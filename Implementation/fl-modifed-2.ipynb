# %% [markdown]
# # modification
# 1) unfreeze last 2 blocks other than FCL
# 2) fedprox instead of fed avg
# 3) no scheduler
#
# additonally
#
# 1) unfreezing 6th layer
# 2) added class weights balancer in the loss

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import copy
from collections import OrderedDict, Counter
import numpy as np
from collections import OrderedDict

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
from torchvision.models import efficientnet_b3, EfficientNet_B3_Weights

from sklearn.metrics import classification_report

# %%
class Net(nn.Module):
    def __init__(self, num_classes=6):
        super().__init__()
        # Load the base EfficientNet model with pre-trained weights
        self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

        # 1. Freeze the entire backbone initially
        for p in self.base.parameters():
            p.requires_grad = False

        # 2. PARTIAL UNFREEZE: Unfreeze the last two blocks (features.7 and features.8)
        # EfficientNet features are in blocks (0 to 8). We unfreeze the last few.
        # Unfreeze features.7 (Block 7)
        for p in self.base.features[6].parameters():
            p.requires_grad = True
        
        for p in self.base.features[7].parameters():
            p.requires_grad = True

        # Unfreeze features.8 (Block 8, which contains the final convolution layer)
        for p in self.base.features[8].parameters():
            p.requires_grad = True

        # 3. Replace and Unfreeze the final fully connected (FC) classifier
        num_ftrs = self.base.classifier[-1].in_features
        self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

        for p in self.base.classifier.parameters():
            p.requires_grad = True

    def forward(self, x):
        return self.base(x)

# %%
img_tf = Compose([
    Resize((256, 256)),
    ToTensor(),
    Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
DATA_ROOT = "/kaggle/input/distributed-dataset/Splitted_data"

def load_client_data(client_id):
    path = os.path.join(DATA_ROOT, f"Client_{client_id}")
    dataset = ImageFolder(path, transform=img_tf)

    n = len(dataset)
    t = int(0.8 * n)
    v = n - t

    train_ds, val_ds = random_split(dataset, [t, v], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)
    return train_loader, val_loader

# %%
def local_train(model, loader, epochs, lr, device):
    model.to(device)
    model.train()

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            loss = crit(model(x), y)
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
from sklearn.metrics import classification_report

def local_eval(model, data_loader, device,class_weights):
    model.eval()
    model.to(device)
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    criterion = nn.CrossEntropyLoss(weight=class_weights)

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)

    # Generate a detailed classification report
    report = classification_report(all_labels, all_preds, output_dict=True, zero_division=0)

    return avg_loss, report

# %%
def local_train_fedprox(model, loader, epochs, lr, mu, device,class_weights):
    model.to(device)
    model.train()

    w_global = OrderedDict(copy.deepcopy(model.state_dict()))

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss(weight=class_weights)

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()

            # --- 1. Standard Loss (Cross-Entropy) ---
            loss = crit(model(x), y)

            # --- 2. Proximal Term (FedProx) ---
            proximal_term = 0.0

            # Iterate through all local model parameters (w)
            for name, param in model.named_parameters():
                if name in w_global:
                    # Calculate ||w - w^t||^2 for each layer
                    # Note: w_global[name] is already on CPU due to deepcopy,
                    # so we move it to the current device for calculation.
                    proximal_term += torch.sum((param - w_global[name].to(device)) ** 2)

            # Add the proximal term to the loss: Loss + (mu/2) * ||w - w^t||^2
            loss += (mu / 2.0) * proximal_term

            # --- 3. Backpropagation ---
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
def fed_avg(models):
    avg = copy.deepcopy(models[0])
    for k in avg.keys():
        for i in range(1, len(models)):
            avg[k] += models[i][k]
        avg[k] = avg[k] / len(models)
    return avg

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLIENTS = 3
ROUNDS = 10
LOCAL_EPOCHS = 10
LR = 0.0001
MU = 0.01
NUM_CLASSES = 6

global_model = Net()

# Load all client validation data once
client_val_loaders = {}
for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    client_val_loaders[cid] = val_loader

# Variables to track the best overall metrics
best_global_accuracy = -1.0
best_metrics_report = None
best_round_info = {"round": -1, "client_id": -1}

def print_aligned_report(report, title):
    """Prints the classification report dictionary in a nicely aligned table."""
    print(f"\n--- {title} ---")

    # Define header with appropriate fixed widths
    # class: 10, precision: 12, recall: 10, f1-score: 12, support: 10
    header = f"{'class':<10}{'precision':<12}{'recall':<10}{'f1-score':<12}{'support':<10}"
    print(header)
    print("-" * len(header))

    for label in sorted([k for k in report.keys() if k.isdigit()]):
        metrics = report[label]
        print(f"{label:<10}   {metrics['precision']:.4f}   {metrics['recall']:.4f}    {metrics['f1-score']:.4f}     {metrics['support']:<10}")
    print("-" * len(header))
    macro_avg = report['macro avg']
    weighted_avg = report['weighted avg']
    total_support = int(weighted_avg['support'])
    print(f"{'accuracy':<10}{'':<12}{'':<10}{report['accuracy']:.4f}{total_support:<10}")

global_class_counts = Counter()


for cid in range(1, NUM_CLIENTS + 1):
    train_loader, _ = load_client_data(cid)
    for _, labels in train_loader:
        global_class_counts.update(labels.tolist())


class_counts = [global_class_counts[i] for i in range(NUM_CLASSES)]
print(f"Global Training Class Counts: {class_counts}")
max_count = max(c for c in class_counts if c > 0) # Find max of classes that actually exist
weights = [max_count / count if count > 0 else 0 for count in class_counts]
class_weights = torch.tensor(weights, dtype=torch.float32).to(DEVICE)


print("Starting FL Training with Round-wise Validation and Best Metrics Tracking...")

for r in range(ROUNDS):
    print(f"\n----- Round {r+1} (Training) -----")

    client_weights = []

    # ----- CLIENT UPDATE (Train locally) -----
    for cid in range(1, NUM_CLIENTS + 1):
        train_loader, _ = load_client_data(cid)

        local_model = copy.deepcopy(global_model)
        updated_weights = local_train_fedprox(local_model, train_loader, LOCAL_EPOCHS, LR, MU, DEVICE, class_weights)
        # updated_weights = local_train(local_model, train_loader, LOCAL_EPOCHS, LR, DEVICE)
        client_weights.append(updated_weights)
        print(f"  Client {cid} finished local training.")

    # ----- SERVER AGGREGATION -----
    new_global_weights = fed_avg(client_weights)
    global_model.load_state_dict(new_global_weights)
    print("Server aggregated weights (FedAvg).")


    # ----- GLOBAL MODEL EVALUATION (Validation) -----
    print(f"\n----- Round {r+1} (Validation) -----")

    for cid in range(1, NUM_CLIENTS + 1):
        val_loader = client_val_loaders[cid]
        loss, report = local_eval(global_model, val_loader, DEVICE,class_weights)

        current_accuracy = report['accuracy']

        print(f"\nClient {cid} Global Model Validation (Round {r+1}): Loss: {loss:.4f} | Accuracy: {current_accuracy:.4f}")

        # Print detailed, aligned report
        print_aligned_report(report, f"Class-wise Metrics (Client {cid})")


        # Check if this is the best accuracy found so far
        if current_accuracy > best_global_accuracy:
            best_global_accuracy = current_accuracy
            best_metrics_report = copy.deepcopy(report)
            best_round_info["round"] = r + 1
            best_round_info["client_id"] = cid

    print("\n" + "="*50)


print("\nFL Training Completed.")

# ----- FINAL BEST METRICS REPORT -----
print("\n" + "="*50)
print("             BEST GLOBAL MODEL METRICS             ")
print(f" (Achieved in Round {best_round_info['round']}, on Client {best_round_info['client_id']}'s validation set)")
print("="*50)

if best_metrics_report:
    print_aligned_report(best_metrics_report, "Best Model Class-wise Performance")
    print(f"\nBest Validation Accuracy: {best_global_accuracy:.4f}")
    print(f"Best Val Loss: {best_metrics_report.get('loss', 'N/A')}")
else:
    print("No validation results recorded.")
# Out:
# Global Training Class Counts: [361, 104, 1890, 419, 373, 214]
# Starting FL Training with Round-wise Validation and Best Metrics Tracking...
#
# ----- Round 1 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 1 (Validation) -----
#
# Client 1 Global Model Validation (Round 1): Loss: 0.9906 | Accuracy: 0.7958
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6250   0.5000    0.5556     30
# 1            0.8571   0.6000    0.7059     10
# 2            0.9313   0.9198    0.9255     162
# 3            0.6731   0.8750    0.7609     40
# 4            0.4667   0.5833    0.5185     24
# 5            0.6364   0.3889    0.4828     18
# ------------------------------------------------------
# accuracy                        0.7958284
#
# Client 2 Global Model Validation (Round 1): Loss: 0.9923 | Accuracy: 0.8029
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.4412   0.7895    0.5660     19
# 1            0.8000   0.2857    0.4211     14
# 2            0.9745   0.9053    0.9387     169
# 3            0.7209   0.8158    0.7654     38
# 4            0.4839   0.6250    0.5455     24
# 5            0.6667   0.4000    0.5000     15
# ------------------------------------------------------
# accuracy                        0.8029279
#
# Client 3 Global Model Validation (Round 1): Loss: 1.0645 | Accuracy: 0.7698
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5625   0.6923    0.6207     39
# 1            0.7000   0.6364    0.6667     11
# 2            0.9470   0.9346    0.9408     153
# 3            0.5926   0.6957    0.6400     23
# 4            0.4444   0.4848    0.4638     33
# 5            0.8333   0.2632    0.4000     19
# ------------------------------------------------------
# accuracy                        0.7698278
#
# ==================================================
#
# ----- Round 2 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 2 (Validation) -----
#
# Client 1 Global Model Validation (Round 2): Loss: 0.8402 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7200   0.6000    0.6545     30
# 1            0.8333   1.0000    0.9091     10
# 2            0.9618   0.9321    0.9467     162
# 3            0.7447   0.8750    0.8046     40
# 4            0.4839   0.6250    0.5455     24
# 5            0.7500   0.5000    0.6000     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 2): Loss: 1.0142 | Accuracy: 0.8351
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.4688   0.7895    0.5882     19
# 1            0.7778   0.5000    0.6087     14
# 2            0.9873   0.9172    0.9509     169
# 3            0.8000   0.8421    0.8205     38
# 4            0.4667   0.5833    0.5185     24
# 5            0.9091   0.6667    0.7692     15
# ------------------------------------------------------
# accuracy                        0.8351279
#
# Client 3 Global Model Validation (Round 2): Loss: 1.0542 | Accuracy: 0.8058
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6222   0.7179    0.6667     39
# 1            0.6154   0.7273    0.6667     11
# 2            0.9671   0.9608    0.9639     153
# 3            0.7500   0.6522    0.6977     23
# 4            0.4412   0.4545    0.4478     33
# 5            0.7857   0.5789    0.6667     19
# ------------------------------------------------------
# accuracy                        0.8058278
#
# ==================================================
#
# ----- Round 3 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 3 (Validation) -----
#
# Client 1 Global Model Validation (Round 3): Loss: 0.9074 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7273   0.5333    0.6154     30
# 1            0.7500   0.9000    0.8182     10
# 2            0.9623   0.9444    0.9533     162
# 3            0.7907   0.8500    0.8193     40
# 4            0.4571   0.6667    0.5424     24
# 5            0.7692   0.5556    0.6452     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 3): Loss: 1.1300 | Accuracy: 0.8602
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5000   0.8421    0.6275     19
# 1            0.8000   0.5714    0.6667     14
# 2            0.9937   0.9290    0.9602     169
# 3            0.8462   0.8684    0.8571     38
# 4            0.5517   0.6667    0.6038     24
# 5            0.9091   0.6667    0.7692     15
# ------------------------------------------------------
# accuracy                        0.8602279
#
# Client 3 Global Model Validation (Round 3): Loss: 1.2024 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6364   0.7179    0.6747     39
# 1            0.5833   0.6364    0.6087     11
# 2            0.9673   0.9673    0.9673     153
# 3            0.7727   0.7391    0.7556     23
# 4            0.4375   0.4242    0.4308     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 4 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 4 (Validation) -----
#
# Client 1 Global Model Validation (Round 4): Loss: 1.0126 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7500   0.9000    0.8182     10
# 2            0.9627   0.9568    0.9598     162
# 3            0.7907   0.8500    0.8193     40
# 4            0.4242   0.5833    0.4912     24
# 5            0.8333   0.5556    0.6667     18
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 4): Loss: 1.1819 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.8000   0.5714    0.6667     14
# 2            0.9938   0.9467    0.9697     169
# 3            0.8293   0.8947    0.8608     38
# 4            0.5333   0.6667    0.5926     24
# 5            1.0000   0.6667    0.8000     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 4): Loss: 1.3885 | Accuracy: 0.8094
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6279   0.6923    0.6585     39
# 1            0.6364   0.6364    0.6364     11
# 2            0.9673   0.9673    0.9673     153
# 3            0.7200   0.7826    0.7500     23
# 4            0.4242   0.4242    0.4242     33
# 5            0.8462   0.5789    0.6875     19
# ------------------------------------------------------
# accuracy                        0.8094278
#
# ==================================================
#
# ----- Round 5 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 5 (Validation) -----
#
# Client 1 Global Model Validation (Round 5): Loss: 1.0149 | Accuracy: 0.8662
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9636   0.9815    0.9725     162
# 3            0.7955   0.8750    0.8333     40
# 4            0.5172   0.6250    0.5660     24
# 5            1.0000   0.5556    0.7143     18
# ------------------------------------------------------
# accuracy                        0.8662284
#
# Client 2 Global Model Validation (Round 5): Loss: 1.1696 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5517   0.8421    0.6667     19
# 1            0.8000   0.5714    0.6667     14
# 2            0.9938   0.9467    0.9697     169
# 3            0.8718   0.8947    0.8831     38
# 4            0.5517   0.6667    0.6038     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 5): Loss: 1.5130 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6222   0.7179    0.6667     39
# 1            0.5833   0.6364    0.6087     11
# 2            0.9675   0.9739    0.9707     153
# 3            0.8095   0.7391    0.7727     23
# 4            0.4375   0.4242    0.4308     33
# 5            0.7857   0.5789    0.6667     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 6 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 6 (Validation) -----
#
# Client 1 Global Model Validation (Round 6): Loss: 1.0669 | Accuracy: 0.8486
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9632   0.9691    0.9662     162
# 3            0.7857   0.8250    0.8049     40
# 4            0.4516   0.5833    0.5091     24
# 5            0.8333   0.5556    0.6667     18
# ------------------------------------------------------
# accuracy                        0.8486284
#
# Client 2 Global Model Validation (Round 6): Loss: 1.2984 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5357   0.7895    0.6383     19
# 1            0.8000   0.5714    0.6667     14
# 2            0.9938   0.9467    0.9697     169
# 3            0.8095   0.8947    0.8500     38
# 4            0.5714   0.6667    0.6154     24
# 5            1.0000   0.6667    0.8000     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 6): Loss: 1.6253 | Accuracy: 0.8165
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6364   0.7179    0.6747     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9677   0.9804    0.9740     153
# 3            0.7917   0.8261    0.8085     23
# 4            0.4333   0.3939    0.4127     33
# 5            0.7333   0.5789    0.6471     19
# ------------------------------------------------------
# accuracy                        0.8165278
#
# ==================================================
#
# ----- Round 7 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 7 (Validation) -----
#
# Client 1 Global Model Validation (Round 7): Loss: 1.0994 | Accuracy: 0.8521
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9632   0.9691    0.9662     162
# 3            0.8095   0.8500    0.8293     40
# 4            0.4483   0.5417    0.4906     24
# 5            0.7857   0.6111    0.6875     18
# ------------------------------------------------------
# accuracy                        0.8521284
#
# Client 2 Global Model Validation (Round 7): Loss: 1.3820 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5714   0.8421    0.6809     19
# 1            0.8889   0.5714    0.6957     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8293   0.8947    0.8608     38
# 4            0.5333   0.6667    0.5926     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 7): Loss: 1.7375 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6279   0.6923    0.6585     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9677   0.9804    0.9740     153
# 3            0.8182   0.7826    0.8000     23
# 4            0.4062   0.3939    0.4000     33
# 5            0.7500   0.6316    0.6857     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 8 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 8 (Validation) -----
#
# Client 1 Global Model Validation (Round 8): Loss: 1.1608 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6800   0.5667    0.6182     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9568   0.9568    0.9568     162
# 3            0.8421   0.8000    0.8205     40
# 4            0.4118   0.5833    0.4828     24
# 5            0.8333   0.5556    0.6667     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 8): Loss: 1.4648 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5926   0.8421    0.6957     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8293   0.8947    0.8608     38
# 4            0.5333   0.6667    0.5926     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 8): Loss: 1.8964 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6279   0.6923    0.6585     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9675   0.9739    0.9707     153
# 3            0.8182   0.7826    0.8000     23
# 4            0.4118   0.4242    0.4179     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 9 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 9 (Validation) -----
#
# Client 1 Global Model Validation (Round 9): Loss: 1.2282 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9568   0.9568    0.9568     162
# 3            0.8000   0.8000    0.8000     40
# 4            0.4000   0.5833    0.4746     24
# 5            0.9091   0.5556    0.6897     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 9): Loss: 1.3909 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5714   0.8421    0.6809     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8293   0.8947    0.8608     38
# 4            0.5517   0.6667    0.6038     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 9): Loss: 1.8593 | Accuracy: 0.7950
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6098   0.6410    0.6250     39
# 1            0.5455   0.5455    0.5455     11
# 2            0.9673   0.9673    0.9673     153
# 3            0.8095   0.7391    0.7727     23
# 4            0.3611   0.3939    0.3768     33
# 5            0.7500   0.6316    0.6857     19
# ------------------------------------------------------
# accuracy                        0.7950278
#
# ==================================================
#
# ----- Round 10 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 10 (Validation) -----
#
# Client 1 Global Model Validation (Round 10): Loss: 1.2664 | Accuracy: 0.8310
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7083   0.5667    0.6296     30
# 1            0.7692   1.0000    0.8696     10
# 2            0.9509   0.9568    0.9538     162
# 3            0.8378   0.7750    0.8052     40
# 4            0.3824   0.5417    0.4483     24
# 5            0.7692   0.5556    0.6452     18
# ------------------------------------------------------
# accuracy                        0.8310284
#
# Client 2 Global Model Validation (Round 10): Loss: 1.5677 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5926   0.8421    0.6957     19
# 1            0.8750   0.5000    0.6364     14
# 2            1.0000   0.9527    0.9758     169
# 3            0.8500   0.8947    0.8718     38
# 4            0.5000   0.6667    0.5714     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 10): Loss: 2.1241 | Accuracy: 0.8094
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6279   0.6923    0.6585     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9675   0.9739    0.9707     153
# 3            0.7826   0.7826    0.7826     23
# 4            0.4118   0.4242    0.4179     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8094278
#
# ==================================================
#
# FL Training Completed.
#
# ==================================================
#              BEST GLOBAL MODEL METRICS
#  (Achieved in Round 5, on Client 2's validation set)
# ==================================================
#
# --- Best Model Class-wise Performance ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5517   0.8421    0.6667     19
# 1            0.8000   0.5714    0.6667     14
# 2            0.9938   0.9467    0.9697     169
# 3            0.8718   0.8947    0.8831     38
# 4            0.5517   0.6667    0.6038     24
# 5            1.0000   0.7333    0.8462     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Best Validation Accuracy: 0.8781
# Best Val Loss: N/A

# %%
print("\n===== Final Evaluation on Each Client =====")

for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    loss, report = local_eval(global_model, val_loader, DEVICE,class_weights)
    print(f"\nClient {cid} Validation:")
    print("Loss:", loss)
    print("Accuracy:", report["accuracy"])
    print(report["macro avg"])
# Out:
# ===== Final Evaluation on Each Client =====
#
# Client 1 Validation:
# Loss: 1.266433556874593
# Accuracy: 0.8309859154929577
# {'precision': 0.7363176493679923, 'recall': 0.7326131687242797, 'f1-score': 0.7252788264089065, 'support': 284}
#
# Client 2 Validation:
# Loss: 1.5677017685439851
# Accuracy: 0.8781362007168458
# {'precision': 0.8029320987654321, 'recall': 0.7649174711927748, 'f1-score': 0.7661917792352574, 'support': 279}
#
# Client 3 Validation:
# Loss: 2.1241147650612726
# Accuracy: 0.8093525179856115
# {'precision': 0.6908947335611226, 'recall': 0.6598565705444154, 'f1-score': 0.6726036868013909, 'support': 278}
