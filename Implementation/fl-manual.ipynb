# %%
import os
import copy
import numpy as np
from collections import OrderedDict

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
from torchvision.models import efficientnet_b3, EfficientNet_B3_Weights

from sklearn.metrics import classification_report

# %%
# class Net(nn.Module):
#     def __init__(self, num_classes=6):
#         super().__init__()
#         self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

#         # freeze backbone
#         for p in self.base.parameters():
#             p.requires_grad = False

#         # replace FC
#         num_ftrs = self.base.classifier[-1].in_features
#         self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

#         for p in self.base.classifier.parameters():
#             p.requires_grad = True

#     def forward(self, x):
#         return self.base(x)

# %% [markdown]
# ## Unfreezed Final Blocks

# %%
class Net(nn.Module):
    def __init__(self, num_classes=6):
        super().__init__()
        # Load the base EfficientNet model with pre-trained weights
        self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

        # 1. Freeze the entire backbone initially
        for p in self.base.parameters():
            p.requires_grad = False

        # 2. PARTIAL UNFREEZE: Unfreeze the last two blocks (features.7 and features.8)
        # EfficientNet features are in blocks (0 to 8). We unfreeze the last few.
        # Unfreeze features.7 (Block 7)
        for p in self.base.features[7].parameters():
            p.requires_grad = True
        
        # Unfreeze features.8 (Block 8, which contains the final convolution layer)
        for p in self.base.features[8].parameters():
            p.requires_grad = True

        # 3. Replace and Unfreeze the final fully connected (FC) classifier
        num_ftrs = self.base.classifier[-1].in_features
        self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

        # The classifier parameters are now trainable by default, 
        # but we explicitly ensure they are unfreezed for clarity:
        for p in self.base.classifier.parameters():
            p.requires_grad = True

    def forward(self, x):
        return self.base(x)

# %%
img_tf = Compose([
    Resize((256, 256)),
    ToTensor(),
    Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
DATA_ROOT = "/kaggle/input/distributed-dataset/Splitted_data"

def load_client_data(client_id):
    path = os.path.join(DATA_ROOT, f"Client_{client_id}")
    dataset = ImageFolder(path, transform=img_tf)

    n = len(dataset)
    t = int(0.8 * n)
    v = n - t

    train_ds, val_ds = random_split(dataset, [t, v], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)
    return train_loader, val_loader

# %%
def local_train(model, loader, epochs, lr, device):
    model.to(device)
    model.train()

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            loss = crit(model(x), y)
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
from sklearn.metrics import classification_report

def local_eval(model, data_loader, device):
    model.eval()
    model.to(device)
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)
    
    # Generate a detailed classification report
    report = classification_report(all_labels, all_preds, output_dict=True, zero_division=0)
    
    return avg_loss, report

# %%
def fed_avg(models):
    avg = copy.deepcopy(models[0])
    for k in avg.keys():
        for i in range(1, len(models)):
            avg[k] += models[i][k]
        avg[k] = avg[k] / len(models)
    return avg

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLIENTS = 3
ROUNDS = 20
LOCAL_EPOCHS = 20
LR = 0.001

global_model = Net()

# Load all client validation data once
client_val_loaders = {}
for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    client_val_loaders[cid] = val_loader

# Variables to track the best overall metrics
best_global_accuracy = -1.0
best_metrics_report = None
best_round_info = {"round": -1, "client_id": -1} 

def print_aligned_report(report, title):
    """Prints the classification report dictionary in a nicely aligned table."""
    print(f"\n--- {title} ---")
    
    # Define header with appropriate fixed widths
    # class: 10, precision: 12, recall: 10, f1-score: 12, support: 10
    header = f"{'class':<10}{'precision':<12}{'recall':<10}{'f1-score':<12}{'support':<10}"
    print(header)
    print("-" * len(header))
    
    # Print class-wise metrics (0 to 5)
    for label in sorted([k for k in report.keys() if k.isdigit()]):
        metrics = report[label]
        print(f"{label:<10}   {metrics['precision']:.4f}   {metrics['recall']:.4f}    {metrics['f1-score']:.4f}     {metrics['support']:<10}")
        
    # Print averages
    print("-" * len(header))
    macro_avg = report['macro avg']
    weighted_avg = report['weighted avg']
    
    # # Macro Average
    # print(f"{'macro avg':<10}{macro_avg['precision']:.4f}{macro_avg['recall']:.4f}{macro_avg['f1-score']:.4f}{macro_avg['support']:<10}")
    
    # # Weighted Average
    # print(f"{'weighted avg':<10}{weighted_avg['precision']:.4f}{weighted_avg['recall']:.4f}{weighted_avg['f1-score']:.4f}{weighted_avg['support']:<10}")
    
    # Accuracy (printed with f1-score alignment, support is the total number of samples)
    total_support = int(weighted_avg['support'])
    print(f"{'accuracy':<10}{'':<12}{'':<10}{report['accuracy']:.4f}{total_support:<10}")


print("Starting FL Training with Round-wise Validation and Best Metrics Tracking...")

for r in range(ROUNDS):
    print(f"\n----- Round {r+1} (Training) -----")

    client_weights = []

    # ----- CLIENT UPDATE (Train locally) -----
    for cid in range(1, NUM_CLIENTS + 1):
        train_loader, _ = load_client_data(cid)
        
        local_model = copy.deepcopy(global_model)
        updated_weights = local_train(local_model, train_loader, LOCAL_EPOCHS, LR, DEVICE)
        client_weights.append(updated_weights)
        print(f"  Client {cid} finished local training.")

    # ----- SERVER AGGREGATION -----
    new_global_weights = fed_avg(client_weights)
    global_model.load_state_dict(new_global_weights)
    print("Server aggregated weights (FedAvg).")

    
    # ----- GLOBAL MODEL EVALUATION (Validation) -----
    print(f"\n----- Round {r+1} (Validation) -----")

    for cid in range(1, NUM_CLIENTS + 1):
        val_loader = client_val_loaders[cid]
        loss, report = local_eval(global_model, val_loader, DEVICE)
        
        current_accuracy = report['accuracy']

        print(f"\nClient {cid} Global Model Validation (Round {r+1}): Loss: {loss:.4f} | Accuracy: {current_accuracy:.4f}")
        
        # Print detailed, aligned report
        print_aligned_report(report, f"Class-wise Metrics (Client {cid})")


        # Check if this is the best accuracy found so far
        if current_accuracy > best_global_accuracy:
            best_global_accuracy = current_accuracy
            best_metrics_report = copy.deepcopy(report) 
            best_round_info["round"] = r + 1
            best_round_info["client_id"] = cid
    
    print("\n" + "="*50)


print("\nFL Training Completed.")

# ----- FINAL BEST METRICS REPORT -----
print("\n" + "="*50)
print("             BEST GLOBAL MODEL METRICS             ")
print(f" (Achieved in Round {best_round_info['round']}, on Client {best_round_info['client_id']}'s validation set)")
print("="*50)

if best_metrics_report:
    print_aligned_report(best_metrics_report, "Best Model Class-wise Performance")
    print(f"\nBest Validation Accuracy: {best_global_accuracy:.4f}")
    print(f"Best Val Loss: {best_metrics_report.get('loss', 'N/A')}") # Note: 'loss' isn't stored in report dict, but F1/Acc are.
else:
    print("No validation results recorded.")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 186MB/s]
# Starting FL Training with Round-wise Validation and Best Metrics Tracking...
#
# ----- Round 1 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 1 (Validation) -----
#
# Client 1 Global Model Validation (Round 1): Loss: 0.6720 | Accuracy: 0.7852
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6087   0.4667    0.5283     30
# 1            0.5714   0.8000    0.6667     10
# 2            0.9669   0.9012    0.9329     162
# 3            0.6531   0.8000    0.7191     40
# 4            0.4688   0.6250    0.5357     24
# 5            0.5333   0.4444    0.4848     18
# ------------------------------------------------------
# accuracy                        0.7852284
#
# Client 2 Global Model Validation (Round 1): Loss: 0.5493 | Accuracy: 0.8208
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.4783   0.5789    0.5238     19
# 1            0.6429   0.6429    0.6429     14
# 2            0.9935   0.9053    0.9474     169
# 3            0.7805   0.8421    0.8101     38
# 4            0.5000   0.5417    0.5200     24
# 5            0.5238   0.7333    0.6111     15
# ------------------------------------------------------
# accuracy                        0.8208279
#
# Client 3 Global Model Validation (Round 1): Loss: 0.7075 | Accuracy: 0.7626
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6154   0.6154    0.6154     39
# 1            0.5333   0.7273    0.6154     11
# 2            0.9527   0.9216    0.9369     153
# 3            0.4828   0.6087    0.5385     23
# 4            0.4194   0.3939    0.4062     33
# 5            0.7500   0.6316    0.6857     19
# ------------------------------------------------------
# accuracy                        0.7626278
#
# ==================================================
#
# ----- Round 2 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 2 (Validation) -----
#
# Client 1 Global Model Validation (Round 2): Loss: 0.6990 | Accuracy: 0.8134
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6957   0.5333    0.6038     30
# 1            0.5882   1.0000    0.7407     10
# 2            0.9671   0.9074    0.9363     162
# 3            0.7234   0.8500    0.7816     40
# 4            0.4839   0.6250    0.5455     24
# 5            0.6429   0.5000    0.5625     18
# ------------------------------------------------------
# accuracy                        0.8134284
#
# Client 2 Global Model Validation (Round 2): Loss: 0.6224 | Accuracy: 0.8566
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5600   0.7368    0.6364     19
# 1            0.6923   0.6429    0.6667     14
# 2            1.0000   0.9231    0.9600     169
# 3            0.8095   0.8947    0.8500     38
# 4            0.6154   0.6667    0.6400     24
# 5            0.5882   0.6667    0.6250     15
# ------------------------------------------------------
# accuracy                        0.8566279
#
# Client 3 Global Model Validation (Round 2): Loss: 0.7418 | Accuracy: 0.8058
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5952   0.6410    0.6173     39
# 1            0.6429   0.8182    0.7200     11
# 2            0.9733   0.9542    0.9637     153
# 3            0.6400   0.6957    0.6667     23
# 4            0.4483   0.3939    0.4194     33
# 5            0.8333   0.7895    0.8108     19
# ------------------------------------------------------
# accuracy                        0.8058278
#
# ==================================================
#
# ----- Round 3 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 3 (Validation) -----
#
# Client 1 Global Model Validation (Round 3): Loss: 0.7227 | Accuracy: 0.8134
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7200   0.6000    0.6545     30
# 1            0.6667   1.0000    0.8000     10
# 2            0.9608   0.9074    0.9333     162
# 3            0.7273   0.8000    0.7619     40
# 4            0.4286   0.6250    0.5085     24
# 5            0.7500   0.5000    0.6000     18
# ------------------------------------------------------
# accuracy                        0.8134284
#
# Client 2 Global Model Validation (Round 3): Loss: 0.5998 | Accuracy: 0.8674
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.7500   0.6429    0.6923     14
# 2            1.0000   0.9112    0.9536     169
# 3            0.8537   0.9211    0.8861     38
# 4            0.5806   0.7500    0.6545     24
# 5            0.7857   0.7333    0.7586     15
# ------------------------------------------------------
# accuracy                        0.8674279
#
# Client 3 Global Model Validation (Round 3): Loss: 0.8404 | Accuracy: 0.7986
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6250   0.6410    0.6329     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9866   0.9608    0.9735     153
# 3            0.6957   0.6957    0.6957     23
# 4            0.3889   0.4242    0.4058     33
# 5            0.7000   0.7368    0.7179     19
# ------------------------------------------------------
# accuracy                        0.7986278
#
# ==================================================
#
# ----- Round 4 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 4 (Validation) -----
#
# Client 1 Global Model Validation (Round 4): Loss: 0.7788 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7692   0.6667    0.7143     30
# 1            0.6667   1.0000    0.8000     10
# 2            0.9682   0.9383    0.9530     162
# 3            0.7674   0.8250    0.7952     40
# 4            0.4545   0.6250    0.5263     24
# 5            0.9000   0.5000    0.6429     18
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 4): Loss: 0.6036 | Accuracy: 0.8817
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5926   0.8421    0.6957     19
# 1            0.8182   0.6429    0.7200     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8293   0.8947    0.8608     38
# 4            0.5862   0.7083    0.6415     24
# 5            0.9091   0.6667    0.7692     15
# ------------------------------------------------------
# accuracy                        0.8817279
#
# Client 3 Global Model Validation (Round 4): Loss: 0.8664 | Accuracy: 0.8058
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6279   0.6923    0.6585     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9735   0.9608    0.9671     153
# 3            0.7391   0.7391    0.7391     23
# 4            0.4000   0.4242    0.4118     33
# 5            0.8125   0.6842    0.7429     19
# ------------------------------------------------------
# accuracy                        0.8058278
#
# ==================================================
#
# ----- Round 5 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 5 (Validation) -----
#
# Client 1 Global Model Validation (Round 5): Loss: 0.8754 | Accuracy: 0.8310
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8000   0.5333    0.6400     30
# 1            0.6429   0.9000    0.7500     10
# 2            0.9684   0.9444    0.9562     162
# 3            0.7727   0.8500    0.8095     40
# 4            0.3889   0.5833    0.4667     24
# 5            0.8333   0.5556    0.6667     18
# ------------------------------------------------------
# accuracy                        0.8310284
#
# Client 2 Global Model Validation (Round 5): Loss: 0.6404 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5200   0.6842    0.5909     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9290    0.9632     169
# 3            0.8537   0.9211    0.8861     38
# 4            0.5294   0.7500    0.6207     24
# 5            0.8333   0.6667    0.7407     15
# ------------------------------------------------------
# accuracy                        0.8638279
#
# Client 3 Global Model Validation (Round 5): Loss: 0.8779 | Accuracy: 0.7986
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5952   0.6410    0.6173     39
# 1            0.6364   0.6364    0.6364     11
# 2            0.9737   0.9673    0.9705     153
# 3            0.7200   0.7826    0.7500     23
# 4            0.3750   0.3636    0.3692     33
# 5            0.7500   0.6316    0.6857     19
# ------------------------------------------------------
# accuracy                        0.7986278
#
# ==================================================
#
# ----- Round 6 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 6 (Validation) -----
#
# Client 1 Global Model Validation (Round 6): Loss: 0.9332 | Accuracy: 0.8486
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8000   0.6667    0.7273     30
# 1            0.6667   1.0000    0.8000     10
# 2            0.9684   0.9444    0.9562     162
# 3            0.7778   0.8750    0.8235     40
# 4            0.4667   0.5833    0.5185     24
# 5            0.8182   0.5000    0.6207     18
# ------------------------------------------------------
# accuracy                        0.8486284
#
# Client 2 Global Model Validation (Round 6): Loss: 0.6814 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.7273   0.5714    0.6400     14
# 2            1.0000   0.9408    0.9695     169
# 3            0.8462   0.8684    0.8571     38
# 4            0.5161   0.6667    0.5818     24
# 5            1.0000   0.8000    0.8889     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 6): Loss: 0.9513 | Accuracy: 0.8165
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6087   0.7179    0.6588     39
# 1            0.6667   0.5455    0.6000     11
# 2            0.9804   0.9804    0.9804     153
# 3            0.7826   0.7826    0.7826     23
# 4            0.4062   0.3939    0.4000     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8165278
#
# ==================================================
#
# ----- Round 7 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 7 (Validation) -----
#
# Client 1 Global Model Validation (Round 7): Loss: 0.8587 | Accuracy: 0.8239
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8095   0.5667    0.6667     30
# 1            0.6923   0.9000    0.7826     10
# 2            0.9615   0.9259    0.9434     162
# 3            0.7778   0.8750    0.8235     40
# 4            0.4194   0.5417    0.4727     24
# 5            0.5556   0.5556    0.5556     18
# ------------------------------------------------------
# accuracy                        0.8239284
#
# Client 2 Global Model Validation (Round 7): Loss: 0.6932 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5000   0.7895    0.6122     19
# 1            0.8182   0.6429    0.7200     14
# 2            1.0000   0.9349    0.9664     169
# 3            0.8462   0.8684    0.8571     38
# 4            0.6296   0.7083    0.6667     24
# 5            0.7857   0.7333    0.7586     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 7): Loss: 0.9911 | Accuracy: 0.8201
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5882   0.7692    0.6667     39
# 1            0.6667   0.5455    0.6000     11
# 2            0.9868   0.9739    0.9803     153
# 3            0.7308   0.8261    0.7755     23
# 4            0.4615   0.3636    0.4068     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8201278
#
# ==================================================
#
# ----- Round 8 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 8 (Validation) -----
#
# Client 1 Global Model Validation (Round 8): Loss: 0.9940 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.6000    0.6667     30
# 1            0.6667   1.0000    0.8000     10
# 2            0.9684   0.9444    0.9562     162
# 3            0.8049   0.8250    0.8148     40
# 4            0.4375   0.5833    0.5000     24
# 5            0.7143   0.5556    0.6250     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 8): Loss: 0.7230 | Accuracy: 0.8853
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5862   0.8947    0.7083     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9349    0.9664     169
# 3            0.8947   0.8947    0.8947     38
# 4            0.6667   0.7500    0.7059     24
# 5            0.7059   0.8000    0.7500     15
# ------------------------------------------------------
# accuracy                        0.8853279
#
# Client 3 Global Model Validation (Round 8): Loss: 1.0472 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6170   0.7436    0.6744     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9739   0.9739    0.9739     153
# 3            0.7200   0.7826    0.7500     23
# 4            0.4444   0.3636    0.4000     33
# 5            0.7647   0.6842    0.7222     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 9 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 9 (Validation) -----
#
# Client 1 Global Model Validation (Round 9): Loss: 1.0418 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7917   0.6333    0.7037     30
# 1            0.6154   0.8000    0.6957     10
# 2            0.9684   0.9444    0.9562     162
# 3            0.8095   0.8500    0.8293     40
# 4            0.4375   0.5833    0.5000     24
# 5            0.7333   0.6111    0.6667     18
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 9): Loss: 0.6781 | Accuracy: 0.8853
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9527    0.9758     169
# 3            0.8684   0.8684    0.8684     38
# 4            0.6000   0.7500    0.6667     24
# 5            0.9231   0.8000    0.8571     15
# ------------------------------------------------------
# accuracy                        0.8853279
#
# Client 3 Global Model Validation (Round 9): Loss: 1.1810 | Accuracy: 0.7950
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6098   0.6410    0.6250     39
# 1            0.5455   0.5455    0.5455     11
# 2            0.9804   0.9804    0.9804     153
# 3            0.7143   0.6522    0.6818     23
# 4            0.3529   0.3636    0.3582     33
# 5            0.7222   0.6842    0.7027     19
# ------------------------------------------------------
# accuracy                        0.7950278
#
# ==================================================
#
# ----- Round 10 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 10 (Validation) -----
#
# Client 1 Global Model Validation (Round 10): Loss: 0.9671 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7037   0.6333    0.6667     30
# 1            0.6429   0.9000    0.7500     10
# 2            0.9620   0.9383    0.9500     162
# 3            0.8049   0.8250    0.8148     40
# 4            0.4516   0.5833    0.5091     24
# 5            0.8462   0.6111    0.7097     18
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 10): Loss: 0.7507 | Accuracy: 0.8853
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5667   0.8947    0.6939     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9527    0.9758     169
# 3            0.8649   0.8421    0.8533     38
# 4            0.6207   0.7500    0.6792     24
# 5            0.9167   0.7333    0.8148     15
# ------------------------------------------------------
# accuracy                        0.8853279
#
# Client 3 Global Model Validation (Round 10): Loss: 1.1518 | Accuracy: 0.8165
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6444   0.7436    0.6905     39
# 1            0.5833   0.6364    0.6087     11
# 2            0.9613   0.9739    0.9675     153
# 3            0.7500   0.6522    0.6977     23
# 4            0.4375   0.4242    0.4308     33
# 5            0.9286   0.6842    0.7879     19
# ------------------------------------------------------
# accuracy                        0.8165278
#
# ==================================================
#
# ----- Round 11 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 11 (Validation) -----
#
# Client 1 Global Model Validation (Round 11): Loss: 1.1700 | Accuracy: 0.8169
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.5000    0.6000     30
# 1            0.6364   0.7000    0.6667     10
# 2            0.9623   0.9444    0.9533     162
# 3            0.7857   0.8250    0.8049     40
# 4            0.3571   0.6250    0.4545     24
# 5            0.9000   0.5000    0.6429     18
# ------------------------------------------------------
# accuracy                        0.8169284
#
# Client 2 Global Model Validation (Round 11): Loss: 0.7871 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5833   0.7368    0.6512     19
# 1            0.7000   0.5000    0.5833     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8421   0.8421    0.8421     38
# 4            0.5000   0.7500    0.6000     24
# 5            0.9091   0.6667    0.7692     15
# ------------------------------------------------------
# accuracy                        0.8638279
#
# Client 3 Global Model Validation (Round 11): Loss: 1.1846 | Accuracy: 0.8058
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6098   0.6410    0.6250     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9739   0.9739    0.9739     153
# 3            0.7727   0.7391    0.7556     23
# 4            0.4000   0.4848    0.4384     33
# 5            0.9231   0.6316    0.7500     19
# ------------------------------------------------------
# accuracy                        0.8058278
#
# ==================================================
#
# ----- Round 12 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 12 (Validation) -----
#
# Client 1 Global Model Validation (Round 12): Loss: 1.0784 | Accuracy: 0.8239
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.6923   0.9000    0.7826     10
# 2            0.9682   0.9383    0.9530     162
# 3            0.8000   0.8000    0.8000     40
# 4            0.3750   0.6250    0.4688     24
# 5            0.8182   0.5000    0.6207     18
# ------------------------------------------------------
# accuracy                        0.8239284
#
# Client 2 Global Model Validation (Round 12): Loss: 0.7941 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9349    0.9664     169
# 3            0.8947   0.8947    0.8947     38
# 4            0.5294   0.7500    0.6207     24
# 5            0.8333   0.6667    0.7407     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 12): Loss: 1.2708 | Accuracy: 0.8022
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5952   0.6410    0.6173     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9675   0.9739    0.9707     153
# 3            0.8182   0.7826    0.8000     23
# 4            0.4000   0.4242    0.4118     33
# 5            0.7333   0.5789    0.6471     19
# ------------------------------------------------------
# accuracy                        0.8022278
#
# ==================================================
#
# ----- Round 13 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 13 (Validation) -----
#
# Client 1 Global Model Validation (Round 13): Loss: 1.1069 | Accuracy: 0.8275
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6429   0.6000    0.6207     30
# 1            0.7273   0.8000    0.7619     10
# 2            0.9627   0.9568    0.9598     162
# 3            0.7750   0.7750    0.7750     40
# 4            0.4167   0.6250    0.5000     24
# 5            1.0000   0.4444    0.6154     18
# ------------------------------------------------------
# accuracy                        0.8275284
#
# Client 2 Global Model Validation (Round 13): Loss: 0.8516 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5517   0.8421    0.6667     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9527    0.9758     169
# 3            0.8919   0.8684    0.8800     38
# 4            0.5484   0.7083    0.6182     24
# 5            0.9091   0.6667    0.7692     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 13): Loss: 1.3185 | Accuracy: 0.8201
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6222   0.7179    0.6667     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9679   0.9869    0.9773     153
# 3            0.8095   0.7391    0.7727     23
# 4            0.4516   0.4242    0.4375     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8201278
#
# ==================================================
#
# ----- Round 14 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 14 (Validation) -----
#
# Client 1 Global Model Validation (Round 14): Loss: 1.2495 | Accuracy: 0.8204
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7619   0.5333    0.6275     30
# 1            0.7500   0.9000    0.8182     10
# 2            0.9623   0.9444    0.9533     162
# 3            0.7500   0.8250    0.7857     40
# 4            0.3590   0.5833    0.4444     24
# 5            0.8889   0.4444    0.5926     18
# ------------------------------------------------------
# accuracy                        0.8204284
#
# Client 2 Global Model Validation (Round 14): Loss: 0.8104 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5185   0.7368    0.6087     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9408    0.9695     169
# 3            0.8947   0.8947    0.8947     38
# 4            0.5484   0.7083    0.6182     24
# 5            0.7857   0.7333    0.7586     15
# ------------------------------------------------------
# accuracy                        0.8710279
#
# Client 3 Global Model Validation (Round 14): Loss: 1.2483 | Accuracy: 0.8058
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6047   0.6667    0.6341     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9675   0.9739    0.9707     153
# 3            0.7727   0.7391    0.7556     23
# 4            0.4412   0.4545    0.4478     33
# 5            0.7500   0.6316    0.6857     19
# ------------------------------------------------------
# accuracy                        0.8058278
#
# ==================================================
#
# ----- Round 15 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 15 (Validation) -----
#
# Client 1 Global Model Validation (Round 15): Loss: 1.3121 | Accuracy: 0.8063
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.5000    0.6000     30
# 1            0.6667   0.8000    0.7273     10
# 2            0.9563   0.9444    0.9503     162
# 3            0.7561   0.7750    0.7654     40
# 4            0.3333   0.5833    0.4242     24
# 5            0.8889   0.4444    0.5926     18
# ------------------------------------------------------
# accuracy                        0.8063284
#
# Client 2 Global Model Validation (Round 15): Loss: 0.7654 | Accuracy: 0.8746
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5600   0.7368    0.6364     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.9167   0.8684    0.8919     38
# 4            0.5278   0.7917    0.6333     24
# 5            0.8333   0.6667    0.7407     15
# ------------------------------------------------------
# accuracy                        0.8746279
#
# Client 3 Global Model Validation (Round 15): Loss: 1.3251 | Accuracy: 0.8094
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6486   0.6154    0.6316     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9804   0.9804    0.9804     153
# 3            0.8095   0.7391    0.7727     23
# 4            0.3810   0.4848    0.4267     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8094278
#
# ==================================================
#
# ----- Round 16 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 16 (Validation) -----
#
# Client 1 Global Model Validation (Round 16): Loss: 1.2701 | Accuracy: 0.8169
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7727   0.5667    0.6538     30
# 1            0.6923   0.9000    0.7826     10
# 2            0.9620   0.9383    0.9500     162
# 3            0.7619   0.8000    0.7805     40
# 4            0.3514   0.5417    0.4262     24
# 5            0.7500   0.5000    0.6000     18
# ------------------------------------------------------
# accuracy                        0.8169284
#
# Client 2 Global Model Validation (Round 16): Loss: 0.8231 | Accuracy: 0.8674
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.7000   0.5000    0.5833     14
# 2            1.0000   0.9349    0.9664     169
# 3            0.8919   0.8684    0.8800     38
# 4            0.5294   0.7500    0.6207     24
# 5            0.8462   0.7333    0.7857     15
# ------------------------------------------------------
# accuracy                        0.8674279
#
# Client 3 Global Model Validation (Round 16): Loss: 1.3623 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6222   0.7179    0.6667     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9740   0.9804    0.9772     153
# 3            0.8095   0.7391    0.7727     23
# 4            0.4194   0.3939    0.4062     33
# 5            0.7059   0.6316    0.6667     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# ----- Round 17 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 17 (Validation) -----
#
# Client 1 Global Model Validation (Round 17): Loss: 1.2402 | Accuracy: 0.8451
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7308   0.6333    0.6786     30
# 1            0.7500   0.9000    0.8182     10
# 2            0.9565   0.9506    0.9536     162
# 3            0.8500   0.8500    0.8500     40
# 4            0.4286   0.6250    0.5085     24
# 5            0.9000   0.5000    0.6429     18
# ------------------------------------------------------
# accuracy                        0.8451284
#
# Client 2 Global Model Validation (Round 17): Loss: 0.9162 | Accuracy: 0.8746
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5556   0.7895    0.6522     19
# 1            0.7273   0.5714    0.6400     14
# 2            1.0000   0.9408    0.9695     169
# 3            0.8718   0.8947    0.8831     38
# 4            0.5667   0.7083    0.6296     24
# 5            0.8462   0.7333    0.7857     15
# ------------------------------------------------------
# accuracy                        0.8746279
#
# Client 3 Global Model Validation (Round 17): Loss: 1.3677 | Accuracy: 0.8201
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6136   0.6923    0.6506     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9803   0.9739    0.9770     153
# 3            0.7917   0.8261    0.8085     23
# 4            0.4545   0.4545    0.4545     33
# 5            0.8125   0.6842    0.7429     19
# ------------------------------------------------------
# accuracy                        0.8201278
#
# ==================================================
#
# ----- Round 18 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 18 (Validation) -----
#
# Client 1 Global Model Validation (Round 18): Loss: 1.3873 | Accuracy: 0.8275
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7308   0.6333    0.6786     30
# 1            0.6923   0.9000    0.7826     10
# 2            0.9500   0.9383    0.9441     162
# 3            0.8684   0.8250    0.8462     40
# 4            0.4062   0.5417    0.4643     24
# 5            0.6000   0.5000    0.5455     18
# ------------------------------------------------------
# accuracy                        0.8275284
#
# Client 2 Global Model Validation (Round 18): Loss: 0.9546 | Accuracy: 0.8853
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5806   0.9474    0.7200     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9527    0.9758     169
# 3            0.8421   0.8421    0.8421     38
# 4            0.6296   0.7083    0.6667     24
# 5            0.9167   0.7333    0.8148     15
# ------------------------------------------------------
# accuracy                        0.8853279
#
# Client 3 Global Model Validation (Round 18): Loss: 1.4600 | Accuracy: 0.8165
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6364   0.7179    0.6747     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9742   0.9869    0.9805     153
# 3            0.7391   0.7391    0.7391     23
# 4            0.4194   0.3939    0.4062     33
# 5            0.8000   0.6316    0.7059     19
# ------------------------------------------------------
# accuracy                        0.8165278
#
# ==================================================
#
# ----- Round 19 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 19 (Validation) -----
#
# Client 1 Global Model Validation (Round 19): Loss: 1.3184 | Accuracy: 0.8345
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7308   0.6333    0.6786     30
# 1            0.7000   0.7000    0.7000     10
# 2            0.9509   0.9568    0.9538     162
# 3            0.8500   0.8500    0.8500     40
# 4            0.4000   0.5833    0.4746     24
# 5            0.8000   0.4444    0.5714     18
# ------------------------------------------------------
# accuracy                        0.8345284
#
# Client 2 Global Model Validation (Round 19): Loss: 1.0255 | Accuracy: 0.8781
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5667   0.8947    0.6939     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9408    0.9695     169
# 3            0.8919   0.8684    0.8800     38
# 4            0.5806   0.7500    0.6545     24
# 5            0.8333   0.6667    0.7407     15
# ------------------------------------------------------
# accuracy                        0.8781279
#
# Client 3 Global Model Validation (Round 19): Loss: 1.3909 | Accuracy: 0.8201
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6444   0.7436    0.6905     39
# 1            0.5556   0.4545    0.5000     11
# 2            0.9805   0.9869    0.9837     153
# 3            0.7727   0.7391    0.7556     23
# 4            0.4412   0.4545    0.4478     33
# 5            0.7857   0.5789    0.6667     19
# ------------------------------------------------------
# accuracy                        0.8201278
#
# ==================================================
#
# ----- Round 20 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 20 (Validation) -----
#
# Client 1 Global Model Validation (Round 20): Loss: 1.3571 | Accuracy: 0.8239
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30
# 1            0.7273   0.8000    0.7619     10
# 2            0.9509   0.9568    0.9538     162
# 3            0.8421   0.8000    0.8205     40
# 4            0.3421   0.5417    0.4194     24
# 5            0.8182   0.5000    0.6207     18
# ------------------------------------------------------
# accuracy                        0.8239284
#
# Client 2 Global Model Validation (Round 20): Loss: 0.9747 | Accuracy: 0.8674
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5600   0.7368    0.6364     19
# 1            0.8571   0.4286    0.5714     14
# 2            1.0000   0.9467    0.9726     169
# 3            0.8500   0.8947    0.8718     38
# 4            0.5143   0.7500    0.6102     24
# 5            0.8333   0.6667    0.7407     15
# ------------------------------------------------------
# accuracy                        0.8674279
#
# Client 3 Global Model Validation (Round 20): Loss: 1.4545 | Accuracy: 0.8129
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6667   0.7179    0.6914     39
# 1            0.6000   0.5455    0.5714     11
# 2            0.9740   0.9804    0.9772     153
# 3            0.7391   0.7391    0.7391     23
# 4            0.4000   0.4242    0.4118     33
# 5            0.7857   0.5789    0.6667     19
# ------------------------------------------------------
# accuracy                        0.8129278
#
# ==================================================
#
# FL Training Completed.
#
# ==================================================
#              BEST GLOBAL MODEL METRICS
#  (Achieved in Round 8, on Client 2's validation set)
# ==================================================
#
# --- Best Model Class-wise Performance ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5862   0.8947    0.7083     19
# 1            0.8000   0.5714    0.6667     14
# 2            1.0000   0.9349    0.9664     169
# 3            0.8947   0.8947    0.8947     38
# 4            0.6667   0.7500    0.7059     24
# 5            0.7059   0.8000    0.7500     15
# ------------------------------------------------------
# accuracy                        0.8853279
#
# Best Validation Accuracy: 0.8853
# Best Val Loss: N/A

# %%
print("\n===== Final Evaluation on Each Client =====")

for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    loss, report = local_eval(global_model, val_loader, DEVICE)

    print(f"\nClient {cid} Validation:")
    print("Loss:", loss)
    print("Accuracy:", report["accuracy"])
    print(report["macro avg"])
# Out:
# ===== Final Evaluation on Each Client =====
#
# Client 1 Validation:
# Loss: 1.357139743036694
# Accuracy: 0.823943661971831
# {'precision': 0.7366192919919526, 'recall': 0.6941872427983539, 'f1-score': 0.7029696106846819, 'support': 284}
#
# Client 2 Validation:
# Loss: 0.9747350530491935
# Accuracy: 0.8673835125448028
# {'precision': 0.7691269841269842, 'recall': 0.7372604341227823, 'f1-score': 0.73385694812549, 'support': 279}
#
# Client 3 Validation:
# Loss: 1.454487446281645
# Accuracy: 0.8129496402877698
# {'precision': 0.6942562268649225, 'recall': 0.6643526079520158, 'f1-score': 0.6762578500866602, 'support': 278}
