# %% [markdown]
# # modification
# 1) unfreeze last 2 blocks other than FCL
# 2) fedprox instead of fed avg
# additonally
#
# 1) unfreezing 6th layer
# 2) added class weights balancer in the loss
# 3) added cosine scheduler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import copy
from collections import OrderedDict, Counter
import numpy as np
from collections import OrderedDict\

import torch
import torch.nn as nn
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
from torchvision.models import efficientnet_b3, EfficientNet_B3_Weights

from sklearn.metrics import classification_report

# %%
class Net(nn.Module):
    def __init__(self, num_classes=6):
        super().__init__()
        # Load the base EfficientNet model with pre-trained weights
        self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

        # 1. Freeze the entire backbone initially
        for p in self.base.parameters():
            p.requires_grad = False

        # 2. PARTIAL UNFREEZE: Unfreeze the last two blocks (features.7 and features.8)
        # EfficientNet features are in blocks (0 to 8). We unfreeze the last few.
        # Unfreeze features.7 (Block 7)
        for p in self.base.features[6].parameters():
            p.requires_grad = True

        for p in self.base.features[7].parameters():
            p.requires_grad = True

        # Unfreeze features.8 (Block 8, which contains the final convolution layer)
        for p in self.base.features[8].parameters():
            p.requires_grad = True

        # 3. Replace and Unfreeze the final fully connected (FC) classifier
        num_ftrs = self.base.classifier[-1].in_features
        self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

        for p in self.base.classifier.parameters():
            p.requires_grad = True

    def forward(self, x):
        return self.base(x)

# %%
img_tf = Compose([
    Resize((256, 256)),
    ToTensor(),
    Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
DATA_ROOT = "/content/drive/MyDrive/Datasets/Splitted_data"

def load_client_data(client_id):
    path = os.path.join(DATA_ROOT, f"Client_{client_id}")
    dataset = ImageFolder(path, transform=img_tf)

    n = len(dataset)
    t = int(0.8 * n)
    v = n - t

    train_ds, val_ds = random_split(dataset, [t, v], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)
    return train_loader, val_loader

# %%
def local_train(model, loader, epochs, lr, device):
    model.to(device)
    model.train()

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            loss = crit(model(x), y)
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
from sklearn.metrics import classification_report

def local_eval(model, data_loader, device,class_weights):
    model.eval()
    model.to(device)
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    criterion = nn.CrossEntropyLoss(weight=class_weights)

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)

    # Generate a detailed classification report
    report = classification_report(all_labels, all_preds, output_dict=True, zero_division=0)

    return avg_loss, report

# %%
def local_train_fedprox(model, loader, epochs, lr, mu, device,class_weights):
    model.to(device)
    model.train()

    w_global = OrderedDict(copy.deepcopy(model.state_dict()))

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss(weight=class_weights)

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()

            # --- 1. Standard Loss (Cross-Entropy) ---
            loss = crit(model(x), y)

            # --- 2. Proximal Term (FedProx) ---
            proximal_term = 0.0

            # Iterate through all local model parameters (w)
            for name, param in model.named_parameters():
                if name in w_global:
                    # Calculate ||w - w^t||^2 for each layer
                    # Note: w_global[name] is already on CPU due to deepcopy,
                    # so we move it to the current device for calculation.
                    proximal_term += torch.sum((param - w_global[name].to(device)) ** 2)

            # Add the proximal term to the loss: Loss + (mu/2) * ||w - w^t||^2
            loss += (mu / 2.0) * proximal_term

            # --- 3. Backpropagation ---
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
def fed_avg(models):
    avg = copy.deepcopy(models[0])
    for k in avg.keys():
        for i in range(1, len(models)):
            avg[k] += models[i][k]
        avg[k] = avg[k] / len(models)
    return avg

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLIENTS = 3
ROUNDS = 10
LOCAL_EPOCHS = 10
LR = 0.0001
MU = 0.01
NUM_CLASSES = 6

global_model = Net()
global_optimizer = torch.optim.Adam(global_model.parameters(), lr=LR)
scheduler = CosineAnnealingLR(global_optimizer, T_max=ROUNDS, eta_min=1e-7)


# Load all client validation data once
client_val_loaders = {}
for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    client_val_loaders[cid] = val_loader

# Variables to track the best overall metrics
best_global_accuracy = -1.0
best_metrics_report = None
best_round_info = {"round": -1, "client_id": -1}

def print_aligned_report(report, title):
    """Prints the classification report dictionary in a nicely aligned table."""
    print(f"\n--- {title} ---")

    # Define header with appropriate fixed widths
    # class: 10, precision: 12, recall: 10, f1-score: 12, support: 10
    header = f"{'class':<10}{'precision':<12}{'recall':<10}{'f1-score':<12}{'support':<10}"
    print(header)
    print("-" * len(header))

    for label in sorted([k for k in report.keys() if k.isdigit()]):
        metrics = report[label]
        print(f"{label:<10}   {metrics['precision']:.4f}   {metrics['recall']:.4f}    {metrics['f1-score']:.4f}     {metrics['support']:<10}")
    print("-" * len(header))
    macro_avg = report['macro avg']
    weighted_avg = report['weighted avg']
    total_support = int(weighted_avg['support'])
    print(f"{'accuracy':<10}{'':<12}{'':<10}{report['accuracy']:.4f}{total_support:<10}")

global_class_counts = Counter()


for cid in range(1, NUM_CLIENTS + 1):
    train_loader, _ = load_client_data(cid)
    for _, labels in train_loader:
        global_class_counts.update(labels.tolist())


class_counts = [global_class_counts[i] for i in range(NUM_CLASSES)]
print(f"Global Training Class Counts: {class_counts}")
max_count = max(c for c in class_counts if c > 0) # Find max of classes that actually exist
weights = [max_count / count if count > 0 else 0 for count in class_counts]
class_weights = torch.tensor(weights, dtype=torch.float32).to(DEVICE)


print("Starting FL Training with Round-wise Validation and Best Metrics Tracking...")

for r in range(ROUNDS):
    print(f"\n----- Round {r+1} (Training) -----")
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.8f}")

    client_weights = []

    # ----- CLIENT UPDATE (Train locally) -----
    for cid in range(1, NUM_CLIENTS + 1):
        train_loader, _ = load_client_data(cid)

        local_model = copy.deepcopy(global_model)
        updated_weights = local_train_fedprox(local_model, train_loader, LOCAL_EPOCHS, current_lr, MU, DEVICE, class_weights)
        # updated_weights = local_train(local_model, train_loader, LOCAL_EPOCHS, LR, DEVICE)
        client_weights.append(updated_weights)
        print(f"  Client {cid} finished local training.")

    # ----- SERVER AGGREGATION -----
    new_global_weights = fed_avg(client_weights)
    global_model.load_state_dict(new_global_weights)
    print("Server aggregated weights (FedAvg).")
    scheduler.step()


    # ----- GLOBAL MODEL EVALUATION (Validation) -----
    print(f"\n----- Round {r+1} (Validation) -----")

    for cid in range(1, NUM_CLIENTS + 1):
        val_loader = client_val_loaders[cid]
        loss, report = local_eval(global_model, val_loader, DEVICE,class_weights)

        current_accuracy = report['accuracy']

        print(f"\nClient {cid} Global Model Validation (Round {r+1}): Loss: {loss:.4f} | Accuracy: {current_accuracy:.4f}")

        # Print detailed, aligned report
        print_aligned_report(report, f"Class-wise Metrics (Client {cid})")


        # Check if this is the best accuracy found so far
        if current_accuracy > best_global_accuracy:
            best_global_accuracy = current_accuracy
            best_metrics_report = copy.deepcopy(report)
            best_round_info["round"] = r + 1
            best_round_info["client_id"] = cid

    print("\n" + "="*50)


print("\nFL Training Completed.")

# ----- FINAL BEST METRICS REPORT -----
print("\n" + "="*50)
print("             BEST GLOBAL MODEL METRICS             ")
print(f" (Achieved in Round {best_round_info['round']}, on Client {best_round_info['client_id']}'s validation set)")
print("="*50)

if best_metrics_report:
    print_aligned_report(best_metrics_report, "Best Model Class-wise Performance")
    print(f"\nBest Validation Accuracy: {best_global_accuracy:.4f}")
    print(f"Best Val Loss: {best_metrics_report.get('loss', 'N/A')}")
else:
    print("No validation results recorded.")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 195MB/s]
# Global Training Class Counts: [363, 115, 1906, 424, 368, 212]
# Starting FL Training with Round-wise Validation and Best Metrics Tracking...
#
# ----- Round 1 (Training) -----
# Current Learning Rate: 0.00010000
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 1 (Validation) -----
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Client 1 Global Model Validation (Round 1): Loss: 1.0718 | Accuracy: 0.7887
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7200   0.6000    0.6545     30.0
# 1            0.6000   0.6000    0.6000     10.0
# 2            0.9202   0.9259    0.9231     162.0
# 3            0.7174   0.8250    0.7674     40.0
# 4            0.3636   0.5000    0.4211     24.0
# 5            0.7143   0.2778    0.4000     18.0
# ------------------------------------------------------
# accuracy                        0.7887284
#
# Client 2 Global Model Validation (Round 1): Loss: 0.8643 | Accuracy: 0.8421
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7143   0.8621    0.7812     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9693   0.9186    0.9433     172.0
# 3            0.6667   0.7742    0.7164     31.0
# 4            0.5806   0.5806    0.5806     31.0
# 5            0.8000   0.6667    0.7273     18.0
# ------------------------------------------------------
# accuracy                        0.8421285
#
# Client 3 Global Model Validation (Round 1): Loss: 1.0541 | Accuracy: 0.7814
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6286   0.8148    0.7097     27.0
# 1            0.7500   0.6000    0.6667     10.0
# 2            0.9250   0.9136    0.9193     162.0
# 3            0.6842   0.8387    0.7536     31.0
# 4            0.4615   0.3871    0.4211     31.0
# 5            0.3333   0.2222    0.2667     18.0
# ------------------------------------------------------
# accuracy                        0.7814279
#
# ==================================================
#
# ----- Round 2 (Training) -----
# Current Learning Rate: 0.00009756
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 2 (Validation) -----
#
# Client 1 Global Model Validation (Round 2): Loss: 1.0501 | Accuracy: 0.8204
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.6000    0.6667     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9557   0.9321    0.9437     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.3824   0.5417    0.4483     24.0
# 5            0.7273   0.4444    0.5517     18.0
# ------------------------------------------------------
# accuracy                        0.8204284
#
# Client 2 Global Model Validation (Round 2): Loss: 0.7522 | Accuracy: 0.9018
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8125   0.8966    0.8525     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9881   0.9651    0.9765     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6364   0.6774    0.6562     31.0
# 5            0.9231   0.6667    0.7742     18.0
# ------------------------------------------------------
# accuracy                        0.9018285
#
# Client 3 Global Model Validation (Round 2): Loss: 1.0676 | Accuracy: 0.8172
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7586   0.8148    0.7857     27.0
# 1            0.8889   0.8000    0.8421     10.0
# 2            0.9437   0.9321    0.9379     162.0
# 3            0.7778   0.9032    0.8358     31.0
# 4            0.4000   0.3871    0.3934     31.0
# 5            0.4667   0.3889    0.4242     18.0
# ------------------------------------------------------
# accuracy                        0.8172279
#
# ==================================================
#
# ----- Round 3 (Training) -----
# Current Learning Rate: 0.00009046
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 3 (Validation) -----
#
# Client 1 Global Model Validation (Round 3): Loss: 1.1363 | Accuracy: 0.8521
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8000   0.6667    0.7273     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9688   0.9568    0.9627     162.0
# 3            0.7778   0.8750    0.8235     40.0
# 4            0.4643   0.5417    0.5000     24.0
# 5            0.7500   0.5000    0.6000     18.0
# ------------------------------------------------------
# accuracy                        0.8521284
#
# Client 2 Global Model Validation (Round 3): Loss: 0.8225 | Accuracy: 0.9053
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7812   0.8621    0.8197     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9883   0.9826    0.9854     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.6452   0.6452    0.6452     31.0
# 5            0.9231   0.6667    0.7742     18.0
# ------------------------------------------------------
# accuracy                        0.9053285
#
# Client 3 Global Model Validation (Round 3): Loss: 1.2773 | Accuracy: 0.8495
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7097   0.8148    0.7586     27.0
# 1            0.8889   0.8000    0.8421     10.0
# 2            0.9688   0.9568    0.9627     162.0
# 3            0.8056   0.9355    0.8657     31.0
# 4            0.4800   0.3871    0.4286     31.0
# 5            0.6111   0.6111    0.6111     18.0
# ------------------------------------------------------
# accuracy                        0.8495279
#
# ==================================================
#
# ----- Round 4 (Training) -----
# Current Learning Rate: 0.00007941
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 4 (Validation) -----
#
# Client 1 Global Model Validation (Round 4): Loss: 1.1821 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7692   0.6667    0.7143     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9686   0.9506    0.9595     162.0
# 3            0.8049   0.8250    0.8148     40.0
# 4            0.4194   0.5417    0.4727     24.0
# 5            0.6923   0.5000    0.5806     18.0
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 4): Loss: 0.8355 | Accuracy: 0.9088
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7812   0.8621    0.8197     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9883   0.9826    0.9854     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.6452   0.6452    0.6452     31.0
# 5            0.9286   0.7222    0.8125     18.0
# ------------------------------------------------------
# accuracy                        0.9088285
#
# Client 3 Global Model Validation (Round 4): Loss: 1.2769 | Accuracy: 0.8423
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6774   0.7778    0.7241     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9745   0.9444    0.9592     162.0
# 3            0.8056   0.9355    0.8657     31.0
# 4            0.4815   0.4194    0.4483     31.0
# 5            0.6111   0.6111    0.6111     18.0
# ------------------------------------------------------
# accuracy                        0.8423279
#
# ==================================================
#
# ----- Round 5 (Training) -----
# Current Learning Rate: 0.00006549
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 5 (Validation) -----
#
# Client 1 Global Model Validation (Round 5): Loss: 1.2334 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.7000    0.7241     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9506   0.9506    0.9506     162.0
# 3            0.7857   0.8250    0.8049     40.0
# 4            0.4444   0.5000    0.4706     24.0
# 5            0.8333   0.5556    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 5): Loss: 1.0197 | Accuracy: 0.9018
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7500   0.8276    0.7869     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9882   0.9767    0.9825     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6562   0.6774    0.6667     31.0
# 5            0.9231   0.6667    0.7742     18.0
# ------------------------------------------------------
# accuracy                        0.9018285
#
# Client 3 Global Model Validation (Round 5): Loss: 1.3970 | Accuracy: 0.8602
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6875   0.8148    0.7458     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9753   0.9753    0.9753     162.0
# 3            0.8000   0.9032    0.8485     31.0
# 4            0.5200   0.4194    0.4643     31.0
# 5            0.7333   0.6111    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8602279
#
# ==================================================
#
# ----- Round 6 (Training) -----
# Current Learning Rate: 0.00005005
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 6 (Validation) -----
#
# Client 1 Global Model Validation (Round 6): Loss: 1.2694 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7692   0.6667    0.7143     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9684   0.9444    0.9563     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.4375   0.5833    0.5000     24.0
# 5            0.8333   0.5556    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 6): Loss: 1.0383 | Accuracy: 0.8947
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7667   0.7931    0.7797     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9881   0.9651    0.9765     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6364   0.6774    0.6562     31.0
# 5            0.8125   0.7222    0.7647     18.0
# ------------------------------------------------------
# accuracy                        0.8947285
#
# Client 3 Global Model Validation (Round 6): Loss: 1.4722 | Accuracy: 0.8710
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6667   0.8148    0.7333     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9815   0.9815    0.9815     162.0
# 3            0.8286   0.9355    0.8788     31.0
# 4            0.5833   0.4516    0.5091     31.0
# 5            0.7333   0.6111    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8710279
#
# ==================================================
#
# ----- Round 7 (Training) -----
# Current Learning Rate: 0.00003461
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 7 (Validation) -----
#
# Client 1 Global Model Validation (Round 7): Loss: 1.3163 | Accuracy: 0.8451
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7692   0.6667    0.7143     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9684   0.9444    0.9563     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.4516   0.5833    0.5091     24.0
# 5            0.8333   0.5556    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8451284
#
# Client 2 Global Model Validation (Round 7): Loss: 1.1604 | Accuracy: 0.8877
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7333   0.7586    0.7458     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9882   0.9709    0.9795     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6176   0.6774    0.6462     31.0
# 5            0.7857   0.6111    0.6875     18.0
# ------------------------------------------------------
# accuracy                        0.8877285
#
# Client 3 Global Model Validation (Round 7): Loss: 1.5740 | Accuracy: 0.8530
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6452   0.7407    0.6897     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9812   0.9691    0.9752     162.0
# 3            0.8056   0.9355    0.8657     31.0
# 4            0.5185   0.4516    0.4828     31.0
# 5            0.6667   0.5556    0.6061     18.0
# ------------------------------------------------------
# accuracy                        0.8530279
#
# ==================================================
#
# ----- Round 8 (Training) -----
# Current Learning Rate: 0.00002069
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 8 (Validation) -----
#
# Client 1 Global Model Validation (Round 8): Loss: 1.2934 | Accuracy: 0.8345
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7917   0.6333    0.7037     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9684   0.9444    0.9563     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.4000   0.5833    0.4746     24.0
# 5            0.8182   0.5000    0.6207     18.0
# ------------------------------------------------------
# accuracy                        0.8345284
#
# Client 2 Global Model Validation (Round 8): Loss: 1.1328 | Accuracy: 0.8877
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7241   0.7241    0.7241     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9882   0.9709    0.9795     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6364   0.6774    0.6562     31.0
# 5            0.7500   0.6667    0.7059     18.0
# ------------------------------------------------------
# accuracy                        0.8877285
#
# Client 3 Global Model Validation (Round 8): Loss: 1.5084 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6774   0.7778    0.7241     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9812   0.9691    0.9752     162.0
# 3            0.8108   0.9677    0.8824     31.0
# 4            0.5600   0.4516    0.5000     31.0
# 5            0.6875   0.6111    0.6471     18.0
# ------------------------------------------------------
# accuracy                        0.8638279
#
# ==================================================
#
# ----- Round 9 (Training) -----
# Current Learning Rate: 0.00000964
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 9 (Validation) -----
#
# Client 1 Global Model Validation (Round 9): Loss: 1.3356 | Accuracy: 0.8310
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7917   0.6333    0.7037     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9684   0.9444    0.9563     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.3939   0.5417    0.4561     24.0
# 5            0.6923   0.5000    0.5806     18.0
# ------------------------------------------------------
# accuracy                        0.8310284
#
# Client 2 Global Model Validation (Round 9): Loss: 1.1378 | Accuracy: 0.8877
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7241   0.7241    0.7241     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9882   0.9709    0.9795     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6364   0.6774    0.6562     31.0
# 5            0.7500   0.6667    0.7059     18.0
# ------------------------------------------------------
# accuracy                        0.8877285
#
# Client 3 Global Model Validation (Round 9): Loss: 1.5351 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6667   0.7407    0.7018     27.0
# 1            0.8889   0.8000    0.8421     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8108   0.9677    0.8824     31.0
# 4            0.5600   0.4516    0.5000     31.0
# 5            0.6471   0.6111    0.6286     18.0
# ------------------------------------------------------
# accuracy                        0.8638279
#
# ==================================================
#
# ----- Round 10 (Training) -----
# Current Learning Rate: 0.00000254
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 10 (Validation) -----
#
# Client 1 Global Model Validation (Round 10): Loss: 1.3517 | Accuracy: 0.8345
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7917   0.6333    0.7037     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9684   0.9444    0.9563     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.4000   0.5833    0.4746     24.0
# 5            0.8182   0.5000    0.6207     18.0
# ------------------------------------------------------
# accuracy                        0.8345284
#
# Client 2 Global Model Validation (Round 10): Loss: 1.1440 | Accuracy: 0.8912
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7241   0.7241    0.7241     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9882   0.9767    0.9825     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.6364   0.6774    0.6562     31.0
# 5            0.8000   0.6667    0.7273     18.0
# ------------------------------------------------------
# accuracy                        0.8912285
#
# Client 3 Global Model Validation (Round 10): Loss: 1.5272 | Accuracy: 0.8674
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6774   0.7778    0.7241     27.0
# 1            0.8889   0.8000    0.8421     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8333   0.9677    0.8955     31.0
# 4            0.5600   0.4516    0.5000     31.0
# 5            0.6471   0.6111    0.6286     18.0
# ------------------------------------------------------
# accuracy                        0.8674279
#
# ==================================================
#
# FL Training Completed.
#
# ==================================================
#              BEST GLOBAL MODEL METRICS
#  (Achieved in Round 4, on Client 2's validation set)
# ==================================================
#
# --- Best Model Class-wise Performance ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7812   0.8621    0.8197     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9883   0.9826    0.9854     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.6452   0.6452    0.6452     31.0
# 5            0.9286   0.7222    0.8125     18.0
# ------------------------------------------------------
# accuracy                        0.9088285
#
# Best Validation Accuracy: 0.9088
# Best Val Loss: N/A

# %%
print("\n===== Final Evaluation on Each Client =====")

for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    loss, report = local_eval(global_model, val_loader, DEVICE,class_weights)
    print(f"\nClient {cid} Validation:")
    print("Loss:", loss)
    print("Accuracy:", report["accuracy"])
    print(report["macro avg"])
# Out:
# ===== Final Evaluation on Each Client =====
#
# Client 1 Validation:
# Loss: 1.35173985030916
# Accuracy: 0.8345070422535211
# {'precision': 0.7396587446668401, 'recall': 0.7310185185185185, 'f1-score': 0.7221681747677166, 'support': 284.0}
#
# Client 2 Validation:
# Loss: 1.144025166829427
# Accuracy: 0.8912280701754386
# {'precision': 0.7919463396643924, 'recall': 0.7884086682590188, 'f1-score': 0.7887374151609632, 'support': 285.0}
#
# Client 3 Validation:
# Loss: 1.5271898243162367
# Accuracy: 0.8673835125448028
# {'precision': 0.7646778100362788, 'recall': 0.7639253949289792, 'f1-score': 0.7614441973663535, 'support': 279.0}
