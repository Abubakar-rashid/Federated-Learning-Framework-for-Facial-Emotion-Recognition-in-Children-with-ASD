# %% [markdown]
# # modification
# 1) unfreeze last 2 blocks other than FCL
# 2) fedprox instead of fed avg
# 3) no scheduler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import copy
import numpy as np
from collections import OrderedDict

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
from torchvision.models import efficientnet_b3, EfficientNet_B3_Weights

from sklearn.metrics import classification_report

# %%
# class Net(nn.Module):
#     def __init__(self, num_classes=6):
#         super().__init__()
#         self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

#         # freeze backbone
#         for p in self.base.parameters():
#             p.requires_grad = False

#         # replace FC
#         num_ftrs = self.base.classifier[-1].in_features
#         self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

#         for p in self.base.classifier.parameters():
#             p.requires_grad = True

#     def forward(self, x):
#         return self.base(x)

class Net(nn.Module):
    def __init__(self, num_classes=6):
        super().__init__()
        # Load the base EfficientNet model with pre-trained weights
        self.base = efficientnet_b3(weights=EfficientNet_B3_Weights.IMAGENET1K_V1)

        # 1. Freeze the entire backbone initially
        for p in self.base.parameters():
            p.requires_grad = False

        # 2. PARTIAL UNFREEZE: Unfreeze the last two blocks (features.7 and features.8)
        # EfficientNet features are in blocks (0 to 8). We unfreeze the last few.
        # Unfreeze features.7 (Block 7)
        for p in self.base.features[7].parameters():
            p.requires_grad = True

        # Unfreeze features.8 (Block 8, which contains the final convolution layer)
        for p in self.base.features[8].parameters():
            p.requires_grad = True

        # 3. Replace and Unfreeze the final fully connected (FC) classifier
        num_ftrs = self.base.classifier[-1].in_features
        self.base.classifier[-1] = nn.Linear(num_ftrs, num_classes)

        # The classifier parameters are now trainable by default,
        # but we explicitly ensure they are unfreezed for clarity:
        for p in self.base.classifier.parameters():
            p.requires_grad = True

    def forward(self, x):
        return self.base(x)

# %%
img_tf = Compose([
    Resize((256, 256)),
    ToTensor(),
    Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
DATA_ROOT = "/content/drive/MyDrive/Datasets/Splitted_data"

def load_client_data(client_id):
    path = os.path.join(DATA_ROOT, f"Client_{client_id}")
    dataset = ImageFolder(path, transform=img_tf)

    n = len(dataset)
    t = int(0.8 * n)
    v = n - t

    train_ds, val_ds = random_split(dataset, [t, v], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)
    return train_loader, val_loader

# %%
def local_train(model, loader, epochs, lr, device):
    model.to(device)
    model.train()

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            loss = crit(model(x), y)
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
from sklearn.metrics import classification_report

def local_eval(model, data_loader, device):
    model.eval()
    model.to(device)
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)

    # Generate a detailed classification report
    report = classification_report(all_labels, all_preds, output_dict=True, zero_division=0)

    return avg_loss, report

# %%
def local_train_fedprox(model, loader, epochs, lr, mu, device):
    model.to(device)
    model.train()

    # Get the state_dict of the model at the start of the round (w^t)
    # This is the reference point for the proximal term.
    # We convert it to an OrderedDict to avoid referencing the model's parameters directly.
    w_global = OrderedDict(copy.deepcopy(model.state_dict()))

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    crit = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()

            # --- 1. Standard Loss (Cross-Entropy) ---
            loss = crit(model(x), y)

            # --- 2. Proximal Term (FedProx) ---
            proximal_term = 0.0

            # Iterate through all local model parameters (w)
            for name, param in model.named_parameters():
                if name in w_global:
                    # Calculate ||w - w^t||^2 for each layer
                    # Note: w_global[name] is already on CPU due to deepcopy,
                    # so we move it to the current device for calculation.
                    proximal_term += torch.sum((param - w_global[name].to(device)) ** 2)

            # Add the proximal term to the loss: Loss + (mu/2) * ||w - w^t||^2
            loss += (mu / 2.0) * proximal_term

            # --- 3. Backpropagation ---
            loss.backward()
            opt.step()

    return model.state_dict()  # return updated weights

# %%
def fed_avg(models):
    avg = copy.deepcopy(models[0])
    for k in avg.keys():
        for i in range(1, len(models)):
            avg[k] += models[i][k]
        avg[k] = avg[k] / len(models)
    return avg

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLIENTS = 3
ROUNDS = 15
LOCAL_EPOCHS = 18
LR = 0.0001
MU = 0.01

global_model = Net()

# Load all client validation data once
client_val_loaders = {}
for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    client_val_loaders[cid] = val_loader

# Variables to track the best overall metrics
best_global_accuracy = -1.0
best_metrics_report = None
best_round_info = {"round": -1, "client_id": -1}

def print_aligned_report(report, title):
    """Prints the classification report dictionary in a nicely aligned table."""
    print(f"\n--- {title} ---")

    # Define header with appropriate fixed widths
    # class: 10, precision: 12, recall: 10, f1-score: 12, support: 10
    header = f"{'class':<10}{'precision':<12}{'recall':<10}{'f1-score':<12}{'support':<10}"
    print(header)
    print("-" * len(header))

    # Print class-wise metrics (0 to 5)
    for label in sorted([k for k in report.keys() if k.isdigit()]):
        metrics = report[label]
        print(f"{label:<10}   {metrics['precision']:.4f}   {metrics['recall']:.4f}    {metrics['f1-score']:.4f}     {metrics['support']:<10}")

    # Print averages
    print("-" * len(header))
    macro_avg = report['macro avg']
    weighted_avg = report['weighted avg']

    # # Macro Average
    # print(f"{'macro avg':<10}{macro_avg['precision']:.4f}{macro_avg['recall']:.4f}{macro_avg['f1-score']:.4f}{macro_avg['support']:<10}")

    # # Weighted Average
    # print(f"{'weighted avg':<10}{weighted_avg['precision']:.4f}{weighted_avg['recall']:.4f}{weighted_avg['f1-score']:.4f}{weighted_avg['support']:<10}")

    # Accuracy (printed with f1-score alignment, support is the total number of samples)
    total_support = int(weighted_avg['support'])
    print(f"{'accuracy':<10}{'':<12}{'':<10}{report['accuracy']:.4f}{total_support:<10}")


print("Starting FL Training with Round-wise Validation and Best Metrics Tracking...")

for r in range(ROUNDS):
    print(f"\n----- Round {r+1} (Training) -----")

    client_weights = []

    # ----- CLIENT UPDATE (Train locally) -----
    for cid in range(1, NUM_CLIENTS + 1):
        train_loader, _ = load_client_data(cid)

        local_model = copy.deepcopy(global_model)
        updated_weights = local_train_fedprox(local_model, train_loader, LOCAL_EPOCHS, LR, MU, DEVICE)
        # updated_weights = local_train(local_model, train_loader, LOCAL_EPOCHS, LR, DEVICE)
        client_weights.append(updated_weights)
        print(f"  Client {cid} finished local training.")

    # ----- SERVER AGGREGATION -----
    new_global_weights = fed_avg(client_weights)
    global_model.load_state_dict(new_global_weights)
    print("Server aggregated weights (FedAvg).")


    # ----- GLOBAL MODEL EVALUATION (Validation) -----
    print(f"\n----- Round {r+1} (Validation) -----")

    for cid in range(1, NUM_CLIENTS + 1):
        val_loader = client_val_loaders[cid]
        loss, report = local_eval(global_model, val_loader, DEVICE)

        current_accuracy = report['accuracy']

        print(f"\nClient {cid} Global Model Validation (Round {r+1}): Loss: {loss:.4f} | Accuracy: {current_accuracy:.4f}")

        # Print detailed, aligned report
        print_aligned_report(report, f"Class-wise Metrics (Client {cid})")


        # Check if this is the best accuracy found so far
        if current_accuracy > best_global_accuracy:
            best_global_accuracy = current_accuracy
            best_metrics_report = copy.deepcopy(report)
            best_round_info["round"] = r + 1
            best_round_info["client_id"] = cid

    print("\n" + "="*50)


print("\nFL Training Completed.")

# ----- FINAL BEST METRICS REPORT -----
print("\n" + "="*50)
print("             BEST GLOBAL MODEL METRICS             ")
print(f" (Achieved in Round {best_round_info['round']}, on Client {best_round_info['client_id']}'s validation set)")
print("="*50)

if best_metrics_report:
    print_aligned_report(best_metrics_report, "Best Model Class-wise Performance")
    print(f"\nBest Validation Accuracy: {best_global_accuracy:.4f}")
    print(f"Best Val Loss: {best_metrics_report.get('loss', 'N/A')}") # Note: 'loss' isn't stored in report dict, but F1/Acc are.
else:
    print("No validation results recorded.")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 137MB/s]
# Starting FL Training with Round-wise Validation and Best Metrics Tracking...
#
# ----- Round 1 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 1 (Validation) -----
#
# Client 1 Global Model Validation (Round 1): Loss: 0.6943 | Accuracy: 0.7465
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.5517   0.5333    0.5424     30.0
# 1            1.0000   0.2000    0.3333     10.0
# 2            0.8844   0.9444    0.9134     162.0
# 3            0.6591   0.7250    0.6905     40.0
# 4            0.3438   0.4583    0.3929     24.0
# 5            0.2500   0.0556    0.0909     18.0
# ------------------------------------------------------
# accuracy                        0.7465284
#
# Client 2 Global Model Validation (Round 1): Loss: 0.6077 | Accuracy: 0.8281
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7037   0.6552    0.6786     29.0
# 1            0.0000   0.0000    0.0000     4.0
# 2            0.9227   0.9709    0.9462     172.0
# 3            0.7297   0.8710    0.7941     31.0
# 4            0.5556   0.6452    0.5970     31.0
# 5            0.7500   0.1667    0.2727     18.0
# ------------------------------------------------------
# accuracy                        0.8281285
#
# Client 3 Global Model Validation (Round 1): Loss: 0.6725 | Accuracy: 0.7778
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6552   0.7037    0.6786     27.0
# 1            1.0000   0.3000    0.4615     10.0
# 2            0.9123   0.9630    0.9369     162.0
# 3            0.6136   0.8710    0.7200     31.0
# 4            0.4074   0.3548    0.3793     31.0
# 5            0.2000   0.0556    0.0870     18.0
# ------------------------------------------------------
# accuracy                        0.7778279
#
# ==================================================
#
# ----- Round 2 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 2 (Validation) -----
#
# Client 1 Global Model Validation (Round 2): Loss: 0.6055 | Accuracy: 0.8134
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7333   0.7333    0.7333     30.0
# 1            0.7778   0.7000    0.7368     10.0
# 2            0.9325   0.9383    0.9354     162.0
# 3            0.7143   0.7500    0.7317     40.0
# 4            0.4643   0.5417    0.5000     24.0
# 5            0.5833   0.3889    0.4667     18.0
# ------------------------------------------------------
# accuracy                        0.8134284
#
# Client 2 Global Model Validation (Round 2): Loss: 0.4571 | Accuracy: 0.8632
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7273   0.8276    0.7742     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9759   0.9419    0.9586     172.0
# 3            0.7500   0.8710    0.8060     31.0
# 4            0.6333   0.6129    0.6230     31.0
# 5            0.7333   0.6111    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8632285
#
# Client 3 Global Model Validation (Round 2): Loss: 0.5647 | Accuracy: 0.8387
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7000   0.7778    0.7368     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9515   0.9691    0.9602     162.0
# 3            0.7500   0.8710    0.8060     31.0
# 4            0.5000   0.4194    0.4561     31.0
# 5            0.6667   0.4444    0.5333     18.0
# ------------------------------------------------------
# accuracy                        0.8387279
#
# ==================================================
#
# ----- Round 3 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 3 (Validation) -----
#
# Client 1 Global Model Validation (Round 3): Loss: 0.6126 | Accuracy: 0.8239
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8214   0.7667    0.7931     30.0
# 1            0.6154   0.8000    0.6957     10.0
# 2            0.9497   0.9321    0.9408     162.0
# 3            0.7143   0.7500    0.7317     40.0
# 4            0.4643   0.5417    0.5000     24.0
# 5            0.6429   0.5000    0.5625     18.0
# ------------------------------------------------------
# accuracy                        0.8239284
#
# Client 2 Global Model Validation (Round 3): Loss: 0.4451 | Accuracy: 0.8807
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8000   0.8276    0.8136     29.0
# 1            0.5000   1.0000    0.6667     4.0
# 2            0.9763   0.9593    0.9677     172.0
# 3            0.8182   0.8710    0.8438     31.0
# 4            0.6562   0.6774    0.6667     31.0
# 5            0.7692   0.5556    0.6452     18.0
# ------------------------------------------------------
# accuracy                        0.8807285
#
# Client 3 Global Model Validation (Round 3): Loss: 0.6012 | Accuracy: 0.8351
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6452   0.7407    0.6897     27.0
# 1            0.7273   0.8000    0.7619     10.0
# 2            0.9573   0.9691    0.9632     162.0
# 3            0.7647   0.8387    0.8000     31.0
# 4            0.5417   0.4194    0.4727     31.0
# 5            0.6000   0.5000    0.5455     18.0
# ------------------------------------------------------
# accuracy                        0.8351279
#
# ==================================================
#
# ----- Round 4 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 4 (Validation) -----
#
# Client 1 Global Model Validation (Round 4): Loss: 0.6751 | Accuracy: 0.8310
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8148   0.7333    0.7719     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9615   0.9259    0.9434     162.0
# 3            0.7111   0.8000    0.7529     40.0
# 4            0.4667   0.5833    0.5185     24.0
# 5            0.6923   0.5000    0.5806     18.0
# ------------------------------------------------------
# accuracy                        0.8310284
#
# Client 2 Global Model Validation (Round 4): Loss: 0.4944 | Accuracy: 0.8702
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7931   0.7931    0.7931     29.0
# 1            0.5000   0.7500    0.6000     4.0
# 2            0.9819   0.9477    0.9645     172.0
# 3            0.8182   0.8710    0.8438     31.0
# 4            0.5385   0.6774    0.6000     31.0
# 5            0.9167   0.6111    0.7333     18.0
# ------------------------------------------------------
# accuracy                        0.8702285
#
# Client 3 Global Model Validation (Round 4): Loss: 0.6619 | Accuracy: 0.8423
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6471   0.8148    0.7213     27.0
# 1            0.7500   0.9000    0.8182     10.0
# 2            0.9689   0.9630    0.9659     162.0
# 3            0.8065   0.8065    0.8065     31.0
# 4            0.5000   0.4194    0.4561     31.0
# 5            0.6667   0.5556    0.6061     18.0
# ------------------------------------------------------
# accuracy                        0.8423279
#
# ==================================================
#
# ----- Round 5 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 5 (Validation) -----
#
# Client 1 Global Model Validation (Round 5): Loss: 0.6988 | Accuracy: 0.8275
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7600   0.6333    0.6909     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9620   0.9383    0.9500     162.0
# 3            0.7381   0.7750    0.7561     40.0
# 4            0.4412   0.6250    0.5172     24.0
# 5            0.7500   0.5000    0.6000     18.0
# ------------------------------------------------------
# accuracy                        0.8275284
#
# Client 2 Global Model Validation (Round 5): Loss: 0.5236 | Accuracy: 0.8737
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8214   0.7931    0.8070     29.0
# 1            0.5000   0.7500    0.6000     4.0
# 2            0.9819   0.9477    0.9645     172.0
# 3            0.8182   0.8710    0.8438     31.0
# 4            0.5641   0.7097    0.6286     31.0
# 5            0.8462   0.6111    0.7097     18.0
# ------------------------------------------------------
# accuracy                        0.8737285
#
# Client 3 Global Model Validation (Round 5): Loss: 0.6907 | Accuracy: 0.8387
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6129   0.7037    0.6552     27.0
# 1            0.7273   0.8000    0.7619     10.0
# 2            0.9752   0.9691    0.9721     162.0
# 3            0.8387   0.8387    0.8387     31.0
# 4            0.4828   0.4516    0.4667     31.0
# 5            0.6250   0.5556    0.5882     18.0
# ------------------------------------------------------
# accuracy                        0.8387279
#
# ==================================================
#
# ----- Round 6 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 6 (Validation) -----
#
# Client 1 Global Model Validation (Round 6): Loss: 0.7489 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8148   0.7333    0.7719     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9500   0.9383    0.9441     162.0
# 3            0.7381   0.7750    0.7561     40.0
# 4            0.5000   0.6250    0.5556     24.0
# 5            0.7500   0.5000    0.6000     18.0
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 6): Loss: 0.5325 | Accuracy: 0.8807
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7857   0.7586    0.7719     29.0
# 1            0.5000   0.7500    0.6000     4.0
# 2            0.9822   0.9651    0.9736     172.0
# 3            0.8235   0.9032    0.8615     31.0
# 4            0.5833   0.6774    0.6269     31.0
# 5            0.9167   0.6111    0.7333     18.0
# ------------------------------------------------------
# accuracy                        0.8807285
#
# Client 3 Global Model Validation (Round 6): Loss: 0.7266 | Accuracy: 0.8495
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6250   0.7407    0.6780     27.0
# 1            0.7273   0.8000    0.7619     10.0
# 2            0.9755   0.9815    0.9785     162.0
# 3            0.8387   0.8387    0.8387     31.0
# 4            0.5185   0.4516    0.4828     31.0
# 5            0.6667   0.5556    0.6061     18.0
# ------------------------------------------------------
# accuracy                        0.8495279
#
# ==================================================
#
# ----- Round 7 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 7 (Validation) -----
#
# Client 1 Global Model Validation (Round 7): Loss: 0.7746 | Accuracy: 0.8451
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7931   0.7667    0.7797     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9625   0.9506    0.9565     162.0
# 3            0.7805   0.8000    0.7901     40.0
# 4            0.4828   0.5833    0.5283     24.0
# 5            0.6667   0.4444    0.5333     18.0
# ------------------------------------------------------
# accuracy                        0.8451284
#
# Client 2 Global Model Validation (Round 7): Loss: 0.5828 | Accuracy: 0.8667
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7188   0.7931    0.7541     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9819   0.9477    0.9645     172.0
# 3            0.8182   0.8710    0.8438     31.0
# 4            0.5429   0.6129    0.5758     31.0
# 5            0.8571   0.6667    0.7500     18.0
# ------------------------------------------------------
# accuracy                        0.8667285
#
# Client 3 Global Model Validation (Round 7): Loss: 0.7861 | Accuracy: 0.8602
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6364   0.7778    0.7000     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9815   0.9815    0.9815     162.0
# 3            0.8387   0.8387    0.8387     31.0
# 4            0.5385   0.4516    0.4912     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8602279
#
# ==================================================
#
# ----- Round 8 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 8 (Validation) -----
#
# Client 1 Global Model Validation (Round 8): Loss: 0.8276 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7778   0.7000    0.7368     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9625   0.9506    0.9565     162.0
# 3            0.7619   0.8000    0.7805     40.0
# 4            0.4375   0.5833    0.5000     24.0
# 5            0.9000   0.5000    0.6429     18.0
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 8): Loss: 0.6370 | Accuracy: 0.8702
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7097   0.7586    0.7333     29.0
# 1            0.5000   0.7500    0.6000     4.0
# 2            0.9820   0.9535    0.9676     172.0
# 3            0.8235   0.9032    0.8615     31.0
# 4            0.5588   0.6129    0.5846     31.0
# 5            0.9231   0.6667    0.7742     18.0
# ------------------------------------------------------
# accuracy                        0.8702285
#
# Client 3 Global Model Validation (Round 8): Loss: 0.8274 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6562   0.7778    0.7119     27.0
# 1            0.7500   0.9000    0.8182     10.0
# 2            0.9815   0.9815    0.9815     162.0
# 3            0.8438   0.8710    0.8571     31.0
# 4            0.5600   0.4516    0.5000     31.0
# 5            0.6875   0.6111    0.6471     18.0
# ------------------------------------------------------
# accuracy                        0.8638279
#
# ==================================================
#
# ----- Round 9 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 9 (Validation) -----
#
# Client 1 Global Model Validation (Round 9): Loss: 0.8620 | Accuracy: 0.8556
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8148   0.7333    0.7719     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9509   0.9568    0.9538     162.0
# 3            0.8250   0.8250    0.8250     40.0
# 4            0.4839   0.6250    0.5455     24.0
# 5            0.9000   0.5000    0.6429     18.0
# ------------------------------------------------------
# accuracy                        0.8556284
#
# Client 2 Global Model Validation (Round 9): Loss: 0.6407 | Accuracy: 0.8807
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7419   0.7931    0.7667     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9821   0.9593    0.9706     172.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.5588   0.6129    0.5846     31.0
# 5            0.9231   0.6667    0.7742     18.0
# ------------------------------------------------------
# accuracy                        0.8807285
#
# Client 3 Global Model Validation (Round 9): Loss: 0.8410 | Accuracy: 0.8746
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6562   0.7778    0.7119     27.0
# 1            0.8182   0.9000    0.8571     10.0
# 2            0.9816   0.9877    0.9846     162.0
# 3            0.8485   0.9032    0.8750     31.0
# 4            0.6087   0.4516    0.5185     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8746279
#
# ==================================================
#
# ----- Round 10 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 10 (Validation) -----
#
# Client 1 Global Model Validation (Round 10): Loss: 0.8184 | Accuracy: 0.8521
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8077   0.7000    0.7500     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9625   0.9506    0.9565     162.0
# 3            0.7500   0.8250    0.7857     40.0
# 4            0.4839   0.6250    0.5455     24.0
# 5            1.0000   0.5000    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8521284
#
# Client 2 Global Model Validation (Round 10): Loss: 0.6492 | Accuracy: 0.8772
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7333   0.7586    0.7458     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9820   0.9535    0.9676     172.0
# 3            0.8286   0.9355    0.8788     31.0
# 4            0.6000   0.6774    0.6364     31.0
# 5            0.8462   0.6111    0.7097     18.0
# ------------------------------------------------------
# accuracy                        0.8772285
#
# Client 3 Global Model Validation (Round 10): Loss: 0.8671 | Accuracy: 0.8746
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6774   0.7778    0.7241     27.0
# 1            0.8182   0.9000    0.8571     10.0
# 2            0.9815   0.9815    0.9815     162.0
# 3            0.8529   0.9355    0.8923     31.0
# 4            0.5833   0.4516    0.5091     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8746279
#
# ==================================================
#
# ----- Round 11 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 11 (Validation) -----
#
# Client 1 Global Model Validation (Round 11): Loss: 0.8673 | Accuracy: 0.8521
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8000   0.6667    0.7273     30.0
# 1            0.7143   1.0000    0.8333     10.0
# 2            0.9630   0.9630    0.9630     162.0
# 3            0.7857   0.8250    0.8049     40.0
# 4            0.4516   0.5833    0.5091     24.0
# 5            0.9000   0.5000    0.6429     18.0
# ------------------------------------------------------
# accuracy                        0.8521284
#
# Client 2 Global Model Validation (Round 11): Loss: 0.7100 | Accuracy: 0.8877
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7333   0.7586    0.7458     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9822   0.9651    0.9736     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.6176   0.6774    0.6462     31.0
# 5            0.8571   0.6667    0.7500     18.0
# ------------------------------------------------------
# accuracy                        0.8877285
#
# Client 3 Global Model Validation (Round 11): Loss: 0.9557 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6562   0.7778    0.7119     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8485   0.9032    0.8750     31.0
# 4            0.5385   0.4516    0.4912     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8638279
#
# ==================================================
#
# ----- Round 12 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 12 (Validation) -----
#
# Client 1 Global Model Validation (Round 12): Loss: 0.8930 | Accuracy: 0.8486
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8148   0.7333    0.7719     30.0
# 1            0.6923   0.9000    0.7826     10.0
# 2            0.9625   0.9506    0.9565     162.0
# 3            0.7674   0.8250    0.7952     40.0
# 4            0.4667   0.5833    0.5185     24.0
# 5            0.8182   0.5000    0.6207     18.0
# ------------------------------------------------------
# accuracy                        0.8486284
#
# Client 2 Global Model Validation (Round 12): Loss: 0.7403 | Accuracy: 0.8702
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7097   0.7586    0.7333     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9819   0.9477    0.9645     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.5263   0.6452    0.5797     31.0
# 5            0.9167   0.6111    0.7333     18.0
# ------------------------------------------------------
# accuracy                        0.8702285
#
# Client 3 Global Model Validation (Round 12): Loss: 0.9904 | Accuracy: 0.8566
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6333   0.7037    0.6667     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8000   0.9032    0.8485     31.0
# 4            0.5385   0.4516    0.4912     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8566279
#
# ==================================================
#
# ----- Round 13 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 13 (Validation) -----
#
# Client 1 Global Model Validation (Round 13): Loss: 0.9152 | Accuracy: 0.8627
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.8148   0.7333    0.7719     30.0
# 1            0.6429   0.9000    0.7500     10.0
# 2            0.9632   0.9691    0.9662     162.0
# 3            0.8250   0.8250    0.8250     40.0
# 4            0.4839   0.6250    0.5455     24.0
# 5            1.0000   0.5000    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8627284
#
# Client 2 Global Model Validation (Round 13): Loss: 0.7558 | Accuracy: 0.8772
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7000   0.7241    0.7119     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9822   0.9651    0.9736     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.5405   0.6452    0.5882     31.0
# 5            0.9167   0.6111    0.7333     18.0
# ------------------------------------------------------
# accuracy                        0.8772285
#
# Client 3 Global Model Validation (Round 13): Loss: 1.0152 | Accuracy: 0.8638
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6667   0.7407    0.7018     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8056   0.9355    0.8657     31.0
# 4            0.5600   0.4516    0.5000     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8638279
#
# ==================================================
#
# ----- Round 14 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 14 (Validation) -----
#
# Client 1 Global Model Validation (Round 14): Loss: 0.9378 | Accuracy: 0.8415
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7727   0.5667    0.6538     30.0
# 1            0.6429   0.9000    0.7500     10.0
# 2            0.9630   0.9630    0.9630     162.0
# 3            0.8049   0.8250    0.8148     40.0
# 4            0.4167   0.6250    0.5000     24.0
# 5            1.0000   0.5000    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8415284
#
# Client 2 Global Model Validation (Round 14): Loss: 0.7448 | Accuracy: 0.8772
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7407   0.6897    0.7143     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9822   0.9651    0.9736     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.5385   0.6774    0.6000     31.0
# 5            0.8462   0.6111    0.7097     18.0
# ------------------------------------------------------
# accuracy                        0.8772285
#
# Client 3 Global Model Validation (Round 14): Loss: 1.0045 | Accuracy: 0.8602
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6562   0.7778    0.7119     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9812   0.9691    0.9752     162.0
# 3            0.8485   0.9032    0.8750     31.0
# 4            0.5185   0.4516    0.4828     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8602279
#
# ==================================================
#
# ----- Round 15 (Training) -----
#   Client 1 finished local training.
#   Client 2 finished local training.
#   Client 3 finished local training.
# Server aggregated weights (FedAvg).
#
# ----- Round 15 (Validation) -----
#
# Client 1 Global Model Validation (Round 15): Loss: 0.9651 | Accuracy: 0.8380
#
# --- Class-wise Metrics (Client 1) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7391   0.5667    0.6415     30.0
# 1            0.6429   0.9000    0.7500     10.0
# 2            0.9630   0.9630    0.9630     162.0
# 3            0.8000   0.8000    0.8000     40.0
# 4            0.4167   0.6250    0.5000     24.0
# 5            1.0000   0.5000    0.6667     18.0
# ------------------------------------------------------
# accuracy                        0.8380284
#
# Client 2 Global Model Validation (Round 15): Loss: 0.7524 | Accuracy: 0.8632
#
# --- Class-wise Metrics (Client 2) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7143   0.6897    0.7018     29.0
# 1            0.7500   0.7500    0.7500     4.0
# 2            0.9820   0.9535    0.9676     172.0
# 3            0.8485   0.9032    0.8750     31.0
# 4            0.5000   0.6452    0.5634     31.0
# 5            0.8462   0.6111    0.7097     18.0
# ------------------------------------------------------
# accuracy                        0.8632285
#
# Client 3 Global Model Validation (Round 15): Loss: 1.0297 | Accuracy: 0.8530
#
# --- Class-wise Metrics (Client 3) ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.6562   0.7778    0.7119     27.0
# 1            0.8000   0.8000    0.8000     10.0
# 2            0.9814   0.9753    0.9783     162.0
# 3            0.8621   0.8065    0.8333     31.0
# 4            0.4667   0.4516    0.4590     31.0
# 5            0.7059   0.6667    0.6857     18.0
# ------------------------------------------------------
# accuracy                        0.8530279
#
# ==================================================
#
# FL Training Completed.
#
# ==================================================
#              BEST GLOBAL MODEL METRICS
#  (Achieved in Round 11, on Client 2's validation set)
# ==================================================
#
# --- Best Model Class-wise Performance ---
# class     precision   recall    f1-score    support
# ------------------------------------------------------
# 0            0.7333   0.7586    0.7458     29.0
# 1            0.6000   0.7500    0.6667     4.0
# 2            0.9822   0.9651    0.9736     172.0
# 3            0.8788   0.9355    0.9062     31.0
# 4            0.6176   0.6774    0.6462     31.0
# 5            0.8571   0.6667    0.7500     18.0
# ------------------------------------------------------
# accuracy                        0.8877285
#
# Best Validation Accuracy: 0.8877
# Best Val Loss: N/A

# %%
print("\n===== Final Evaluation on Each Client =====")

for cid in range(1, NUM_CLIENTS + 1):
    _, val_loader = load_client_data(cid)
    loss, report = local_eval(global_model, val_loader, DEVICE)

    print(f"\nClient {cid} Validation:")
    print("Loss:", loss)
    print("Accuracy:", report["accuracy"])
    print(report["macro avg"])
# Out:
# ===== Final Evaluation on Each Client =====
#
# Client 1 Validation:
# Loss: 0.9650706417030759
# Accuracy: 0.8380281690140845
# {'precision': 0.7602695345448968, 'recall': 0.7257716049382715, 'f1-score': 0.7201898439319824, 'support': 284.0}
#
# Client 2 Validation:
# Loss: 0.7524362769391801
# Accuracy: 0.8631578947368421
# {'precision': 0.7734933895113536, 'recall': 0.7587736253986869, 'f1-score': 0.7612272849047952, 'support': 285.0}
#
# Client 3 Validation:
# Loss: 1.0297041535377502
# Accuracy: 0.8530465949820788
# {'precision': 0.7453724074587357, 'recall': 0.7463029337581308, 'f1-score': 0.7447094321074195, 'support': 279.0}
